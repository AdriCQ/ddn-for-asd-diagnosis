# %% [markdown]
# ## Deep neural network for ASD classification using resting-state fMRI
#
# This notebook evaluate a deep neural network for ASD diagnosis using functional time series data from brain regions of interest. The used resting-state fMRI data from the ABIDE dataset were preprocessed by the **Preprocessed Connectome Project (PCP)** using four pipelines, involving 1100 subjects from multiple international sites.
#
# ### Configure the loading data
#
#  The parameters necessary for loading our neuroimaging data are defined. The `pipeline` and `atlas` used for preprocessing and ROIs extraction are specified. Additionally, we list all neuroimaging sites available in the dataset and select those we want to include in the analysis by the parameter `sites`.

# %%
# Preprocessing pipeline
pipeline = 'cpac'  

# List of ROIs brain atlas
atlases = ['rois_cc200', 'rois_aal']

# List of all available neuroimaging sites in the dataset
all_sites = [
    'caltech', 'cmu', 'kki', 'leuven_1', 'leuven_2', 'max_mun', 'nyu', 
    'ohsu', 'olin', 'pitt', 'sbl', 'sdsu', 'stanford', 'trinity', 
    'ucla_1', 'ucla_2', 'um_1', 'um_2', 'usm', 'yale'
]

# Sites include in the analysis
sites = all_sites

# Testing site
test_site = 'yale'

# %% [markdown]
# ### Data loading function
#
# Definition of the `load_atlas_data(pipeline, atlas, sites)` function to retrieve subject time series and diagnostic labels from each neuroimaging site in `sites`. This function reads phenotypic information from CSV files, then loads the time series data for each subject. Also handle potential issues, such as missing files or NaN values, to ensure data integrity before analysis.

# %%
import os
import csv
import numpy as np


def load_atlas_data(pipeline, atlases, sites):
    """
    Loads time series and diagnostic labels from neuroimaging data files for the specified sites.
    
    Parameters:
        pipeline (str): Preprocessing pipeline used for the data.
        atlas (str): Atlas defining regions of interest.
        sites (list of str): List of site names to load data from.

    Returns:
        atlas_time_series (dict): Contains time series data for each site.
        atlas_labels (dict): Contains diagnostic labels for each site.
    """

    atlas_time_series = []  # Dictionary to store time series data for each site
    atlas_labels = {}  # Dictionary to store labels for each site
    
    
    for site in sites:
        # Define path for phenotypic data for the current site
        phenotypic_path = f"data/phenotypic/{site}/phenotypic.csv"

        try:
            with open(phenotypic_path, 'r') as file:
                reader = csv.DictReader(file)
                site_labels = []  # List to store labels for each subject at the site

                for row in reader:
                    file_id = row['file_id']  # Unique subject identifier
                    dx_group = row['dx_group']  # Diagnostic group (ASD=1, Control=0)

                    # Define path for the time series data file
                    data_file_path = os.path.join(f"data/{pipeline}/{atlases[0]}/{site}", f"{file_id}_{atlases[0]}.1D")

                    # Check if the data file exists
                    if not os.path.exists(data_file_path):
                        print(f"File Not Found Error: Data file not found at path {data_file_path}")
                        continue
                    
                    data = np.loadtxt(data_file_path)

                    # Check for NaN values and add time series to the site list
                    if np.isnan(data).any():
                        print(f"Value Error: NaN value found for subject {file_id}")
                    else:            
                        site_labels.append(1 if dx_group == '1' else 0)  # Assign 1 for ASD, 0 for control

                # Store loaded data for the current site in the dictionaries
                atlas_labels[site] = np.array(site_labels)
                print(f"Loaded labels {len(site_labels)} subjects from site {site}.")
                
        except FileNotFoundError:
            print(f"File Not Found Error: Phenotypic data not found for site {site}")

    for atlas in atlases:
        atlas_data = {}
        for site in sites:
            # Define path for phenotypic data for the current site
            phenotypic_path = f"data/phenotypic/{site}/phenotypic.csv"

            try:
                with open(phenotypic_path, 'r') as file:
                    reader = csv.DictReader(file)
                    site_time_series = []  # List to store time series for each subject at the site
                
                    for row in reader:
                        file_id = row['file_id']  # Unique subject identifier
                    
                        # Define path for the time series data file
                        data_file_path = os.path.join(f"data/{pipeline}/{atlas}/{site}", f"{file_id}_{atlas}.1D")

                        # Check if the data file exists
                        if not os.path.exists(data_file_path):
                            print(f"File Not Found Error: Data file not found at path {data_file_path}")
                            continue
                        
                        data = np.loadtxt(data_file_path)

                        # Check for NaN values and add time series to the site list
                        if np.isnan(data).any():
                            print(f"Value Error: NaN value found for subject {file_id}")
                        else:
                            site_time_series.append(data)
                    
                    # Store loaded data for the current site in the dictionaries
                    atlas_data[site] = site_time_series
                    print(f"Loaded {len(site_time_series)} subjects from site {site}.")
                    
            except FileNotFoundError:
                print(f"File Not Found Error: Phenotypic data not found for site {site}")
    
        atlas_time_series.append(atlas_data)
    
    return atlas_time_series, atlas_labels

# %% [markdown]
# Load data to be used in the analysis based on specified parameters.

# %%
atlas_time_series, atlas_labels = load_atlas_data(pipeline, atlases, sites)
# Out:
# Loaded labels 38 subjects from site caltech.
# Loaded labels 27 subjects from site cmu.
# Loaded labels 55 subjects from site kki.
# Loaded labels 29 subjects from site leuven_1.
# Loaded labels 35 subjects from site leuven_2.
# Loaded labels 57 subjects from site max_mun.
# Loaded labels 184 subjects from site nyu.
# Loaded labels 28 subjects from site ohsu.
# Loaded labels 36 subjects from site olin.
# Loaded labels 57 subjects from site pitt.
# Loaded labels 30 subjects from site sbl.
# Loaded labels 36 subjects from site sdsu.
# Loaded labels 40 subjects from site stanford.
# Loaded labels 49 subjects from site trinity.
# Loaded labels 73 subjects from site ucla_1.
# Loaded labels 26 subjects from site ucla_2.
# Loaded labels 108 subjects from site um_1.
# Loaded labels 35 subjects from site um_2.
# Loaded labels 101 subjects from site usm.
# Loaded labels 56 subjects from site yale.
# Loaded 38 subjects from site caltech.
# Loaded 27 subjects from site cmu.
# Loaded 55 subjects from site kki.
# Loaded 29 subjects from site leuven_1.
# Loaded 35 subjects from site leuven_2.
# Loaded 57 subjects from site max_mun.
# Loaded 184 subjects from site nyu.
# Loaded 28 subjects from site ohsu.
# Loaded 36 subjects from site olin.
# Loaded 57 subjects from site pitt.
# Loaded 30 subjects from site sbl.
# Loaded 36 subjects from site sdsu.
# Loaded 40 subjects from site stanford.
# Loaded 49 subjects from site trinity.
# Loaded 73 subjects from site ucla_1.
# Loaded 26 subjects from site ucla_2.
# Loaded 108 subjects from site um_1.
# Loaded 35 subjects from site um_2.
# Loaded 101 subjects from site usm.
# Loaded 56 subjects from site yale.
# Loaded 38 subjects from site caltech.
# Loaded 27 subjects from site cmu.
# Loaded 55 subjects from site kki.
# Loaded 29 subjects from site leuven_1.
# Loaded 35 subjects from site leuven_2.
# Loaded 57 subjects from site max_mun.
# Loaded 184 subjects from site nyu.
# Loaded 28 subjects from site ohsu.
# Loaded 36 subjects from site olin.
# Loaded 57 subjects from site pitt.
# Loaded 30 subjects from site sbl.
# Loaded 36 subjects from site sdsu.
# Loaded 40 subjects from site stanford.
# Loaded 49 subjects from site trinity.
# Loaded 73 subjects from site ucla_1.
# Loaded 26 subjects from site ucla_2.
# Loaded 108 subjects from site um_1.
# Loaded 35 subjects from site um_2.
# Loaded 101 subjects from site usm.
# Loaded 56 subjects from site yale.

# %% [markdown]
# ### Tangent space embedding
#
# This method allows the translation of connectivity matrices from fMRI data into a form that is compatible with Euclidean machine learning techniques while preserving the important geometric properties of the data. This technique is particularly useful when analyzing covariance or correlation matrices in tasks involving brain connectivity and classification of neurological conditions.
#
# The workflow used for this notebooks involves two main steps:
#
# **Estimate the reference tangent space**: Calculate the tangent space projection based on the mean covariance matrix of a training population. This establishes the "reference space" against which individual test subjects can later be projected.
#
# **Project subjects onto the reference space**: Using the precomputed reference tangent space from the population, can be project the covariance matrix of a new subjects onto this space. This will yield a tangent space connectivity matrix for the subjects that aligns with those of the population.
#
# #### Create the population data
#
# To maintain a separate testing set, we exclude the `test_site` site data from the main population data used for Estimate the reference tangent space.

# %%
def create_population(time_series_data):
    # Initialize an empty list for the population data 
    population_data = []

    # Loop through the time series data
    for item in time_series_data:
        # Extend each item
        population_data.extend(item)

    print(f"Total subjects in population data: {len(population_data)}")
    return population_data

# %% [markdown]
# #### Estimate the reference tangent space
#
# Calculate the tangent space based on the mean covariance matrix of a training population dataset. This creates a "reference space" that reflects the average connectivity patterns across the population.

# %% [markdown]
# #### Function to estimating tangent space functional connectivity
#
# The `estimate_tangent_space(data)` function calculate the tangent space based on the geometric mean covariance matrix of a training population dataset. This creates a "reference space" that reflects the average connectivity patterns across the population.
#
# The tangent space representation of functional connectivity is a powerful tool for analyzing brain connectivity. It allows the comparison of individual functional connectivity matrices in a standardized space, computed relative to a group average matrix.

# %%
from nilearn.connectome import ConnectivityMeasure

def estimate_tangent_space(data):
    """
    Estimate the tangent space functional connectivity.

    Parameters:
    -----------
    data : list or ndarray
        List or array of time series data for the training population, where each entry corresponds 
        to a subject's time series (time points x regions).

    Returns:
    --------
    ConnectivityMeasure
        Fitted ConnectivityMeasure object configured for tangent space transformation.
    """
    # Instantiate ConnectivityMeasure for tangent space, vectorizing and discarding the diagonal
    connectivity_measure = ConnectivityMeasure(kind='tangent', vectorize=True, discard_diagonal=True)

    # Fit the measure on the population data to establish a reference tangent space
    connectivity_measure.fit(data)

    return connectivity_measure

# %% [markdown]
# ### Function for create deep neural network models
#
# The `build_model(input_shape)` function create DNN models with the following architecture:
#
# Input Layer: Takes in the number of features from the input data.
#
# Dense Layer 1: 1024 neurons, ReLU activation, with L2 regularization to reduce overfitting.
#
# Dense Layer 2: 256 neurons, ReLU activation, L2 regularization.
#
# Output Layer: A single neuron with sigmoid activation for binary classification.
#
# The model is compiled with the Adam optimizer and binary cross-entropy loss, as we aim to classify subjects into two classes. We also include accuracy as a performance metric to track model performance during training and evaluation.

# %%
from keras import layers, models, regularizers

# Define the deep neural network model architecture
def build_model(input_shape):
    """
    Builds and compiles a deep neural network model for binary classification.

    Parameters:
    - input_shape: int, the shape of the input layer, matching the number of features in the dataset

    Returns:
    - model: compiled Keras Sequential model ready for training
    """
    
    model = models.Sequential()

    # Input layer
    model.add(layers.InputLayer(input_shape=input_shape))
    model.add(layers.Dropout(0.2))

    # Hidden layers
    model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dropout(0.4))

    model.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dropout(0.4))

    # Output layer for binary classification (ASD vs. Healthy)
    model.add(layers.Dense(1, activation='sigmoid'))

    # Compile the model with Adam optimizer and binary cross-entropy loss
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %% [markdown]
# ### Training Callbacks
#
# To optimize training, we set up three callbacks:
#
# **EarlyStopping:** Stops training if validation loss doesn't improve for 10 epochs, preventing overfitting and restoring the best weights.
#
# **ReduceLROnPlateau:** Reduces the learning rate by 50% when validation loss plateaus for 5 epochs, ensuring gradual and effective model convergence.
#
# **ModelCheckpoint:** Saves the model with the best validation loss to 'best_model.keras', allowing easy access to the optimal version of the model.

# %%
from keras import callbacks

# Early stopping to prevent overfitting by stopping training when validation loss stops improving
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',             # Monitor validation loss for early stopping
    patience=10,                    # Stop training if val_loss does not improve for 10 epochs
    restore_best_weights=True       # Restore the model weights from the epoch with the lowest val_loss
)

# Reduce learning rate when the validation loss plateaus
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',             # Monitor validation loss for learning rate reduction
    factor=0.5,                     # Reduce learning rate by a factor of 0.5
    patience=5,                     # Trigger after 5 epochs without improvement in val_loss
    min_lr=1e-5                     # Set a floor on the learning rate to avoid overly small values
)

# Save the best model based on validation loss
checkpoint = callbacks.ModelCheckpoint(
    'best_model.keras',             # Filename for the best model
    monitor='val_loss',             # Monitor validation loss for checkpoint saving
    save_best_only=True             # Only save the model when it achieves a new best val_loss
)

# Callbacks list passed to the model
callbacks_list = [early_stopping, reduce_lr, checkpoint]

# %% [markdown]
# ### Function to adjust class balance
#
# The `adjust_class_balance(indices, labels)` function ensures equal representation of all classes by undersampling the majority class(es). This is particularly important in supervised learning, where imbalanced classes can lead to biased models. The function return shuffled list of indices representing a class-balanced subset of the dataset.

# %%
import numpy as np

def adjust_class_balance(indices, labels):
    """
    Adjusts the balance of classes by undersampling the majority class.

    Parameters:
    ----------
    indices : list or ndarray
        Indices of the dataset.
    labels : list or ndarray
        Class labels corresponding to the indices.

    Returns:
    -------
    balanced_indices : ndarray
        Indices of the balanced dataset.
    """
    # Class labels to consider
    CLASS_LABELS = [0, 1]

    # Separate indices by class
    class_indices = {label: [idx for idx in indices if labels[idx] == label] for label in CLASS_LABELS}

    # Determine the minimum class count
    min_class_count = min(len(indices) for indices in class_indices.values())

    # Adjust class balance by undersampling the majority class
    balanced_indices = []
    for label, class_list in class_indices.items():
        if len(class_list) > min_class_count:
            sampled_indices = np.random.choice(class_list, size=min_class_count, replace=False)
            balanced_indices.extend(sampled_indices)
        else:
            balanced_indices.extend(class_list)

    # Shuffle the indices for randomization
    np.random.shuffle(balanced_indices)
    return np.array(balanced_indices)

# %% [markdown]
# ### Stratified cross-validation setup for model training and validation
#
# Set up stratified 10-fold cross-validation for each site (excluding `test_site`) to evaluate model performance across multiple splits. Here’s an overview of the process:
#
# **Stratified k-folds**: StratifiedKFold let to maintain the balance of classes (ASD vs. NC) across each fold, reducing potential bias.
#
# **Fold processing**: For each site, 10 training and validation folds are generated, and indices are stored in the `train_indices` and `val_indices` dictionaries. To ensure class balance after combining all group folds for training data the majority class in each site is undersampling.
#
# **Class balance checks**: For each fold, the balance of ASD and NC samples is shown to confirm each split maintains similar distributions.

# %%
from sklearn.model_selection import StratifiedKFold

# Number of cross-validation folds
n_folds = 10

# Dictionaries for save the training and validation indices
train_indices = {}
val_indices = {}

# Perform stratified k-fold cross-validation for each site, excluding 'test_site' for testing
for site in sites:
    if site == test_site:
        continue

    features = atlas_time_series[site]
    labels = atlas_labels[site]

    # Initialize StratifiedKFold with shuffle to ensure data randomization
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True)
    
    site_train_indices = []
    site_val_indices = []

    # Loop through each fold in the stratified split
    for fold, (train_idx, val_idx) in enumerate(skf.split(features, labels)):
        print(f"Processing fold #{fold} for site `{site}`")
      
        train_idx = adjust_class_balance(train_idx, labels)
        val_idx = adjust_class_balance(val_idx, labels)

        # Append training and validation indices for each fold
        site_train_indices.append(np.array(train_idx))
        site_val_indices.append(np.array(val_idx))
        
        # Print class distribution for training and validation sets for each fold
        print(f"Balance of classes in training -> ASD: {np.count_nonzero(labels[site_train_indices[fold]] == 1)} and TC: {np.count_nonzero(labels[site_train_indices[fold]] == 0)}")
        
        print(f"Balance of classes in validation -> ASD: {np.count_nonzero(labels[site_val_indices[fold]] == 1)} and TC: {np.count_nonzero(labels[site_val_indices[fold]] == 0)}")

    # Store indices for each fold in the dictionaries
    train_indices[site] = site_train_indices
    val_indices[site] = site_val_indices
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 15
#      12 if site == test_site:
#      13     continue
# ---> 15 features = atlas_time_series[site]
#      16 labels = atlas_labels[site]
#      18 # Initialize StratifiedKFold with shuffle to ensure data randomization
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ### Project test set data into the tangent space and evaluating class balance
#
# The test data is transforming by the precomputed reference tangent space and the class balance is evaluated.

# %%
    
site_data = []
for i in range(len(atlases)):
    # Retrieve the connectivity features for the test site
    site_feature_vectors = connectivities[i].transform(atlas_time_series[i][test_site])
    feature_vectors = []
    for value in site_feature_vectors:
        feature_vectors.append(np.array(value))
    site_feature_vectors = np.array(feature_vectors)
    site_data.append(site_feature_vectors) 

combined_list = []
for arrays in zip(site_data[0], site_data[1]):
    # Ensure each array has at least one dimension
    arrays = [np.array(arr) for arr in arrays]

    # Concatenate along the default axis (axis=0)
    combined_array = np.concatenate(arrays)
    combined_list.append(combined_array)   

# Update the dictionary with site-specific feature vectors
atlas_feature_vectors[test_site] = np.array(combined_list)
        
# Print the number of subjects processed for the current site
print(f"Feature vectors for site {test_site}: with {len(combined_list)} subjects and {len(combined_list[0])} features")
# Out:
# Feature vectors for site yale: with 56 subjects and 26570 features

# %%
X_test, y_test = atlas_feature_vectors.get(test_site), atlas_labels.get(test_site)

print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")

print(f"Balance of classes in test - ASD: {np.count_nonzero(y_test == 1)}, TC: {np.count_nonzero(y_test == 0)}")
# Out:
# Shape of X_test: (56, 26570)
# Shape of y_test: (56,)
# Balance of classes in test - ASD: 28, TC: 28

# %% [markdown]
# ### Data Normalization
#
# To standardize the feature values, we use StandardScaler. Each split is normalized independently to prevent data leakage, using the training data mean and variance for scaling the validation and test sets.

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression  # or RandomForestClassifier
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score, mean_squared_error
from sklearn.preprocessing import StandardScaler

total_accuracy_validation = 0
total_sensitivity_validation = 0
total_specificity_validation = 0
total_auc_validation = 0

total_accuracy_test = 0
total_sensitivity_test = 0
total_specificity_test = 0
total_auc_test = 0

# Cross-validation across all splits
for split in range(n_folds):
    print(f"Split # {split + 1}")
    
    X_train, X_validation, y_train, y_validation = [], [], [], []

    # # Aggregate training and validation data from all sites
    for site in sites:
        if site == test_site:
            continue

        # Training and validation data for each site split
        X_train.extend(atlas_feature_vectors[site][train_indices[site][split]])
        X_validation.extend(atlas_feature_vectors[site][val_indices[site][split]])

        y_train.extend(atlas_labels[site][train_indices[site][split]])
        y_validation.extend(atlas_labels[site][val_indices[site][split]])

    # Convert lists to numpy arrays
    X_train, X_validation = map(np.array, [X_train, X_validation])
    y_train, y_validation = map(np.array, [y_train, y_validation])
    
    print(f"Balance of classes in training - ASD: {np.count_nonzero(y_train == 1)}, TC: {np.count_nonzero(y_train == 0)}")
    print(f"Balance of classes in validation - ASD: {np.count_nonzero(y_validation == 1)}, TC: {np.count_nonzero(y_validation == 0)}")

    print(f"Shape of X_train: {X_train.shape}")
    print(f"Shape of y_train: {y_train.shape}")

    print(f"Shape of X_validation: {X_validation.shape}")
    print(f"Shape of y_validation: {y_validation.shape}")

    # Build and train the deep neural network model
    dnn = build_model(X_train.shape[1])

    history = dnn.fit(
        X_train, y_train,
        validation_data=(X_validation, y_validation),
        batch_size=64,
        epochs=200,
        callbacks=callbacks_list
    )

     # Evaluate again in the validations set
    validation_predictions = (dnn.predict(X_validation) > 0.5).astype(int)
    cm_validation = confusion_matrix(y_validation, validation_predictions)
    tn_validation, fp_validation, fn_validation, tp_validation = cm_validation.ravel()

    # Calculate evaluation metrics
    accuracy_validation = (tp_validation + tn_validation) / (tp_validation + tn_validation + fp_validation + fn_validation)
    sensitivity_validation = tp_validation / (tp_validation + fn_validation) if tp_validation + fn_validation > 0 else 0
    specificity_validation = tn_validation / (tn_validation + fp_validation) if tn_validation + fp_validation > 0 else 0
    auc_validation = roc_auc_score(y_validation, dnn.predict(X_validation))

    # Print validation metrics
    print(f"Validation Accuracy: {accuracy_validation*100:.2f}")
    print(f"Validation Sensitivity (Recall): {sensitivity_validation*100:.2f}")
    print(f"Validation Specificity: {specificity_validation*100:.2f}")
    print(f"Validation AUC-ROC Score: {auc_validation*100:.2f}")
    print(f"Validation Confusion Matrix:\n{cm_validation}")
    
    total_accuracy_validation += accuracy_validation
    total_sensitivity_validation += sensitivity_validation
    total_specificity_validation += specificity_validation
    total_auc_validation += auc_validation

    # Print mean validation metrics
    print(f"Validation Mean Accuracy: {(total_accuracy_validation / (split + 1))*100:.2f}")
    print(f"Validation Mean Sensitivity (Recall): {(total_sensitivity_validation / (split + 1))*100:.2f}")
    print(f"Validation Mean Specificity: {(total_specificity_validation / (split + 1))*100:.2f}")
    print(f"Validation Mean AUC-ROC Score: {(total_auc_validation / (split + 1))*100:.2f}")

    # Evaluate in the test set
    test_predictions = (dnn.predict(X_test) > 0.5).astype(int)
    cm_test = confusion_matrix(y_test, test_predictions)
    tn_test, fp_test, fn_test, tp_test = cm_test.ravel()

    # Calculate evaluation metrics
    accuracy_test = (tp_test + tn_test) / (tp_test + tn_test + fp_test + fn_test)
    sensitivity_test = tp_test / (tp_test + fn_test) if tp_test + fn_test > 0 else 0
    specificity_test = tn_test / (tn_test + fp_test) if tn_test + fp_test > 0 else 0
    auc_test = roc_auc_score(y_test, dnn.predict(X_test))

    # Print test metrics
    print(f"Test Accuracy: {accuracy_test*100:.2f}")
    print(f"Test Sensitivity (Recall): {sensitivity_test*100:.2f}")
    print(f"Test Specificity: {specificity_test*100:.2f}")
    print(f"Test AUC-ROC Score: {auc_test*100:.2f}")
    print(f"Test Confusion Matrix:\n{cm_test}")
    
    total_accuracy_test += accuracy_test
    total_sensitivity_test += sensitivity_test
    total_specificity_test += specificity_test
    total_auc_test += auc_test

    # Print mean test metrics
    print(f"Test Mean Accuracy: {(total_accuracy_test / (split + 1))*100:.2f}")
    print(f"Test Mean Sensitivity (Recall): {(total_sensitivity_test / (split + 1))*100:.2f}")
    print(f"Test Mean Specificity: {(total_specificity_test / (split + 1))*100:.2f}")
    print(f"Test Mean AUC-ROC Score: {(total_auc_test / (split + 1))*100:.2f}")
# Out:
# Split # 1
# Balance of classes in training - ASD: 417, TC: 417
# Balance of classes in validation - ASD: 47, TC: 47
# Shape of X_train: (834, 26570)
# Shape of y_train: (834,)
# Shape of X_validation: (94, 26570)
# Shape of y_validation: (94,)
# Epoch 1/200
# 14/14 [==============================] - 4s 199ms/step - loss: 3.0898 - accuracy: 0.6127 - val_loss: 3.2039 - val_accuracy: 0.5851 - lr: 0.0010
# Epoch 2/200
# 14/14 [==============================] - 2s 175ms/step - loss: 2.7215 - accuracy: 0.9580 - val_loss: 3.2016 - val_accuracy: 0.6383 - lr: 0.0010
# Epoch 3/200
# 14/14 [==============================] - 2s 169ms/step - loss: 2.4604 - accuracy: 0.9952 - val_loss: 3.0203 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 4/200
# 14/14 [==============================] - 2s 169ms/step - loss: 2.1058 - accuracy: 1.0000 - val_loss: 2.7027 - val_accuracy: 0.6809 - lr: 0.0010
# Epoch 5/200
# 14/14 [==============================] - 2s 174ms/step - loss: 1.6933 - accuracy: 1.0000 - val_loss: 2.3251 - val_accuracy: 0.6489 - lr: 0.0010
# Epoch 6/200
# 14/14 [==============================] - 2s 168ms/step - loss: 1.3181 - accuracy: 1.0000 - val_loss: 1.9447 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 7/200
# 14/14 [==============================] - 2s 170ms/step - loss: 1.0161 - accuracy: 1.0000 - val_loss: 1.6427 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 8/200
# 14/14 [==============================] - 2s 175ms/step - loss: 0.7888 - accuracy: 1.0000 - val_loss: 1.4556 - val_accuracy: 0.6702 - lr: 0.0010
# Epoch 9/200
# 14/14 [==============================] - 2s 178ms/step - loss: 0.6231 - accuracy: 1.0000 - val_loss: 1.3166 - val_accuracy: 0.6383 - lr: 0.0010
# Epoch 10/200
# 14/14 [==============================] - 2s 173ms/step - loss: 0.5007 - accuracy: 1.0000 - val_loss: 1.2148 - val_accuracy: 0.6277 - lr: 0.0010
# Epoch 11/200
# 14/14 [==============================] - 2s 172ms/step - loss: 0.4177 - accuracy: 1.0000 - val_loss: 1.1489 - val_accuracy: 0.6809 - lr: 0.0010
# Epoch 12/200
# 14/14 [==============================] - 3s 184ms/step - loss: 0.3599 - accuracy: 1.0000 - val_loss: 1.2059 - val_accuracy: 0.6702 - lr: 0.0010
# Epoch 13/200
# 14/14 [==============================] - 3s 192ms/step - loss: 0.3132 - accuracy: 1.0000 - val_loss: 1.2306 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 14/200
# 14/14 [==============================] - 3s 187ms/step - loss: 0.2789 - accuracy: 1.0000 - val_loss: 1.1630 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 15/200
# 14/14 [==============================] - 3s 195ms/step - loss: 0.2439 - accuracy: 1.0000 - val_loss: 1.0409 - val_accuracy: 0.6702 - lr: 0.0010
# Epoch 16/200
# 14/14 [==============================] - 3s 193ms/step - loss: 0.2172 - accuracy: 1.0000 - val_loss: 1.0514 - val_accuracy: 0.6489 - lr: 0.0010
# Epoch 17/200
# 14/14 [==============================] - 3s 232ms/step - loss: 0.2061 - accuracy: 0.9988 - val_loss: 1.1317 - val_accuracy: 0.5957 - lr: 0.0010
# Epoch 18/200
# 14/14 [==============================] - 4s 281ms/step - loss: 0.2385 - accuracy: 0.9988 - val_loss: 1.4013 - val_accuracy: 0.6383 - lr: 0.0010
# Epoch 19/200
# 14/14 [==============================] - 3s 248ms/step - loss: 0.8959 - accuracy: 0.9245 - val_loss: 3.2357 - val_accuracy: 0.6170 - lr: 0.0010
# Epoch 20/200
# 14/14 [==============================] - 4s 275ms/step - loss: 2.6217 - accuracy: 0.8729 - val_loss: 5.0747 - val_accuracy: 0.6170 - lr: 0.0010
# Epoch 21/200
# 14/14 [==============================] - 3s 246ms/step - loss: 3.4866 - accuracy: 0.9472 - val_loss: 4.9661 - val_accuracy: 0.6383 - lr: 5.0000e-04
# Epoch 22/200
# 14/14 [==============================] - 3s 220ms/step - loss: 3.4132 - accuracy: 0.9772 - val_loss: 4.7017 - val_accuracy: 0.7021 - lr: 5.0000e-04
# Epoch 23/200
# 14/14 [==============================] - 3s 235ms/step - loss: 3.1316 - accuracy: 0.9940 - val_loss: 4.4526 - val_accuracy: 0.6596 - lr: 5.0000e-04
# Epoch 24/200
# 14/14 [==============================] - 3s 224ms/step - loss: 2.8224 - accuracy: 0.9988 - val_loss: 4.1731 - val_accuracy: 0.6596 - lr: 5.0000e-04
# Epoch 25/200
# 14/14 [==============================] - 3s 223ms/step - loss: 2.5256 - accuracy: 0.9976 - val_loss: 3.9038 - val_accuracy: 0.6702 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 32ms/step
# 3/3 [==============================] - 0s 28ms/step
# Validation Accuracy: 67.02
# Validation Sensitivity (Recall): 68.09
# Validation Specificity: 65.96
# Validation AUC-ROC Score: 72.43
# Validation Confusion Matrix:
# [[31 16]
#  [15 32]]
# Validation Mean Accuracy: 67.02
# Validation Mean Sensitivity (Recall): 68.09
# Validation Mean Specificity: 65.96
# Validation Mean AUC-ROC Score: 72.43
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 24ms/step
# Test Accuracy: 73.21
# Test Sensitivity (Recall): 78.57
# Test Specificity: 67.86
# Test AUC-ROC Score: 76.40
# Test Confusion Matrix:
# [[19  9]
#  [ 6 22]]
# Test Mean Accuracy: 73.21
# Test Mean Sensitivity (Recall): 78.57
# Test Mean Specificity: 67.86
# Test Mean AUC-ROC Score: 76.40
# Split # 2
# Balance of classes in training - ASD: 416, TC: 416
# Balance of classes in validation - ASD: 48, TC: 48
# Shape of X_train: (832, 26570)
# Shape of y_train: (832,)
# Shape of X_validation: (96, 26570)
# Shape of y_validation: (96,)
# Epoch 1/200
# 13/13 [==============================] - 5s 255ms/step - loss: 3.0901 - accuracy: 0.6022 - val_loss: 3.1362 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 2/200
# 13/13 [==============================] - 3s 220ms/step - loss: 2.6773 - accuracy: 0.9688 - val_loss: 3.1461 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 3/200
# 13/13 [==============================] - 3s 232ms/step - loss: 2.3838 - accuracy: 0.9988 - val_loss: 3.0058 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 4/200
# 13/13 [==============================] - 3s 222ms/step - loss: 1.9894 - accuracy: 0.9988 - val_loss: 2.5696 - val_accuracy: 0.6979 - lr: 0.0010
# Epoch 5/200
# 13/13 [==============================] - 3s 225ms/step - loss: 1.5533 - accuracy: 1.0000 - val_loss: 2.1241 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 6/200
# 13/13 [==============================] - 3s 228ms/step - loss: 1.1695 - accuracy: 0.9988 - val_loss: 1.7871 - val_accuracy: 0.6979 - lr: 0.0010
# Epoch 7/200
# 13/13 [==============================] - 3s 246ms/step - loss: 0.8671 - accuracy: 1.0000 - val_loss: 1.4532 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 8/200
# 13/13 [==============================] - 3s 226ms/step - loss: 0.6401 - accuracy: 1.0000 - val_loss: 1.2373 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 9/200
# 13/13 [==============================] - 3s 222ms/step - loss: 0.4779 - accuracy: 1.0000 - val_loss: 1.0942 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 10/200
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3621 - accuracy: 1.0000 - val_loss: 0.9745 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 11/200
# 13/13 [==============================] - 3s 222ms/step - loss: 0.2823 - accuracy: 1.0000 - val_loss: 0.9112 - val_accuracy: 0.6979 - lr: 0.0010
# Epoch 12/200
# 13/13 [==============================] - 3s 221ms/step - loss: 0.2271 - accuracy: 1.0000 - val_loss: 0.8984 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 13/200
# 13/13 [==============================] - 3s 220ms/step - loss: 0.1868 - accuracy: 1.0000 - val_loss: 0.8397 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 14/200
# 13/13 [==============================] - 3s 226ms/step - loss: 0.1564 - accuracy: 1.0000 - val_loss: 0.7918 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 15/200
# 13/13 [==============================] - 3s 220ms/step - loss: 0.1325 - accuracy: 1.0000 - val_loss: 0.7733 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 16/200
# 13/13 [==============================] - 3s 235ms/step - loss: 0.1152 - accuracy: 1.0000 - val_loss: 0.7610 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 17/200
# 13/13 [==============================] - 3s 244ms/step - loss: 0.1023 - accuracy: 1.0000 - val_loss: 0.7933 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 18/200
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0926 - accuracy: 1.0000 - val_loss: 0.7837 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 19/200
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0859 - accuracy: 1.0000 - val_loss: 0.8116 - val_accuracy: 0.6979 - lr: 0.0010
# Epoch 20/200
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0844 - accuracy: 1.0000 - val_loss: 0.8468 - val_accuracy: 0.6979 - lr: 0.0010
# Epoch 21/200
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0869 - accuracy: 1.0000 - val_loss: 0.8352 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 22/200
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0924 - accuracy: 1.0000 - val_loss: 0.9891 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 23/200
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0942 - accuracy: 1.0000 - val_loss: 1.0246 - val_accuracy: 0.6354 - lr: 5.0000e-04
# Epoch 24/200
# 13/13 [==============================] - 3s 235ms/step - loss: 0.0880 - accuracy: 1.0000 - val_loss: 0.9679 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 25/200
# 13/13 [==============================] - 3s 238ms/step - loss: 0.0793 - accuracy: 1.0000 - val_loss: 0.9005 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 26/200
# 13/13 [==============================] - 3s 235ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 0.8632 - val_accuracy: 0.6667 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 32ms/step
# 3/3 [==============================] - 0s 27ms/step
# Validation Accuracy: 70.83
# Validation Sensitivity (Recall): 68.75
# Validation Specificity: 72.92
# Validation AUC-ROC Score: 75.56
# Validation Confusion Matrix:
# [[35 13]
#  [15 33]]
# Validation Mean Accuracy: 68.93
# Validation Mean Sensitivity (Recall): 68.42
# Validation Mean Specificity: 69.44
# Validation Mean AUC-ROC Score: 74.00
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 23ms/step
# Test Accuracy: 73.21
# Test Sensitivity (Recall): 75.00
# Test Specificity: 71.43
# Test AUC-ROC Score: 83.55
# Test Confusion Matrix:
# [[20  8]
#  [ 7 21]]
# Test Mean Accuracy: 73.21
# Test Mean Sensitivity (Recall): 76.79
# Test Mean Specificity: 69.64
# Test Mean AUC-ROC Score: 79.97
# Split # 3
# Balance of classes in training - ASD: 415, TC: 415
# Balance of classes in validation - ASD: 49, TC: 49
# Shape of X_train: (830, 26570)
# Shape of y_train: (830,)
# Shape of X_validation: (98, 26570)
# Shape of y_validation: (98,)
# Epoch 1/200
# 13/13 [==============================] - 5s 295ms/step - loss: 3.1056 - accuracy: 0.5952 - val_loss: 3.1313 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 2/200
# 13/13 [==============================] - 3s 234ms/step - loss: 2.7114 - accuracy: 0.9614 - val_loss: 3.0763 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 3/200
# 13/13 [==============================] - 3s 236ms/step - loss: 2.4030 - accuracy: 0.9964 - val_loss: 2.8449 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 4/200
# 13/13 [==============================] - 3s 258ms/step - loss: 2.0054 - accuracy: 0.9988 - val_loss: 2.4362 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 5/200
# 13/13 [==============================] - 3s 237ms/step - loss: 1.5668 - accuracy: 1.0000 - val_loss: 2.0040 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 6/200
# 13/13 [==============================] - 3s 261ms/step - loss: 1.1777 - accuracy: 1.0000 - val_loss: 1.6385 - val_accuracy: 0.7041 - lr: 0.0010
# Epoch 7/200
# 13/13 [==============================] - 3s 253ms/step - loss: 0.8765 - accuracy: 0.9976 - val_loss: 1.3819 - val_accuracy: 0.6939 - lr: 0.0010
# Epoch 8/200
# 13/13 [==============================] - 3s 250ms/step - loss: 0.6571 - accuracy: 1.0000 - val_loss: 1.2042 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 9/200
# 13/13 [==============================] - 3s 249ms/step - loss: 0.5009 - accuracy: 1.0000 - val_loss: 1.0747 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 10/200
# 13/13 [==============================] - 3s 258ms/step - loss: 0.3857 - accuracy: 1.0000 - val_loss: 0.9597 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 11/200
# 13/13 [==============================] - 3s 252ms/step - loss: 0.3025 - accuracy: 1.0000 - val_loss: 0.8823 - val_accuracy: 0.7041 - lr: 0.0010
# Epoch 12/200
# 13/13 [==============================] - 3s 249ms/step - loss: 0.2419 - accuracy: 1.0000 - val_loss: 0.8308 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 13/200
# 13/13 [==============================] - 3s 255ms/step - loss: 0.1965 - accuracy: 1.0000 - val_loss: 0.7604 - val_accuracy: 0.7347 - lr: 0.0010
# Epoch 14/200
# 13/13 [==============================] - 3s 243ms/step - loss: 0.1635 - accuracy: 1.0000 - val_loss: 0.7443 - val_accuracy: 0.7347 - lr: 0.0010
# Epoch 15/200
# 13/13 [==============================] - 3s 246ms/step - loss: 0.1393 - accuracy: 1.0000 - val_loss: 0.7223 - val_accuracy: 0.7347 - lr: 0.0010
# Epoch 16/200
# 13/13 [==============================] - 3s 259ms/step - loss: 0.1211 - accuracy: 1.0000 - val_loss: 0.7093 - val_accuracy: 0.7347 - lr: 0.0010
# Epoch 17/200
# 13/13 [==============================] - 3s 250ms/step - loss: 0.1071 - accuracy: 1.0000 - val_loss: 0.6720 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 18/200
# 13/13 [==============================] - 3s 254ms/step - loss: 0.1065 - accuracy: 0.9988 - val_loss: 0.7171 - val_accuracy: 0.6939 - lr: 0.0010
# Epoch 19/200
# 13/13 [==============================] - 3s 247ms/step - loss: 0.1331 - accuracy: 0.9988 - val_loss: 0.7409 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 20/200
# 13/13 [==============================] - 3s 238ms/step - loss: 0.2112 - accuracy: 0.9976 - val_loss: 1.0721 - val_accuracy: 0.6735 - lr: 0.0010
# Epoch 21/200
# 13/13 [==============================] - 3s 253ms/step - loss: 0.4772 - accuracy: 0.9663 - val_loss: 2.3208 - val_accuracy: 0.5816 - lr: 0.0010
# Epoch 22/200
# 13/13 [==============================] - 3s 253ms/step - loss: 1.7725 - accuracy: 0.9084 - val_loss: 3.3997 - val_accuracy: 0.6224 - lr: 0.0010
# Epoch 23/200
# 13/13 [==============================] - 3s 245ms/step - loss: 2.7388 - accuracy: 0.9277 - val_loss: 3.8427 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 24/200
# 13/13 [==============================] - 3s 257ms/step - loss: 2.8272 - accuracy: 0.9723 - val_loss: 3.8076 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 25/200
# 13/13 [==============================] - 3s 243ms/step - loss: 2.6534 - accuracy: 0.9880 - val_loss: 3.4758 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 26/200
# 13/13 [==============================] - 3s 244ms/step - loss: 2.3594 - accuracy: 0.9952 - val_loss: 3.1395 - val_accuracy: 0.7041 - lr: 5.0000e-04
# Epoch 27/200
# 13/13 [==============================] - 3s 251ms/step - loss: 2.0769 - accuracy: 0.9988 - val_loss: 2.8400 - val_accuracy: 0.6735 - lr: 5.0000e-04
# 4/4 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 22ms/step
# Validation Accuracy: 74.49
# Validation Sensitivity (Recall): 67.35
# Validation Specificity: 81.63
# Validation AUC-ROC Score: 80.17
# Validation Confusion Matrix:
# [[40  9]
#  [16 33]]
# Validation Mean Accuracy: 70.78
# Validation Mean Sensitivity (Recall): 68.06
# Validation Mean Specificity: 73.50
# Validation Mean AUC-ROC Score: 76.06
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 26ms/step
# Test Accuracy: 73.21
# Test Sensitivity (Recall): 71.43
# Test Specificity: 75.00
# Test AUC-ROC Score: 82.27
# Test Confusion Matrix:
# [[21  7]
#  [ 8 20]]
# Test Mean Accuracy: 73.21
# Test Mean Sensitivity (Recall): 75.00
# Test Mean Specificity: 71.43
# Test Mean AUC-ROC Score: 80.74
# Split # 4
# Balance of classes in training - ASD: 418, TC: 418
# Balance of classes in validation - ASD: 48, TC: 48
# Shape of X_train: (836, 26570)
# Shape of y_train: (836,)
# Shape of X_validation: (96, 26570)
# Shape of y_validation: (96,)
# Epoch 1/200
# 14/14 [==============================] - 6s 288ms/step - loss: 3.1019 - accuracy: 0.6136 - val_loss: 3.0881 - val_accuracy: 0.6979 - lr: 0.0010
# Epoch 2/200
# 14/14 [==============================] - 3s 244ms/step - loss: 2.7409 - accuracy: 0.9569 - val_loss: 3.0947 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 3/200
# 14/14 [==============================] - 3s 233ms/step - loss: 2.4934 - accuracy: 0.9952 - val_loss: 2.8888 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 4/200
# 14/14 [==============================] - 3s 235ms/step - loss: 2.1491 - accuracy: 0.9988 - val_loss: 2.5107 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 5/200
# 14/14 [==============================] - 3s 242ms/step - loss: 1.7407 - accuracy: 0.9988 - val_loss: 2.1030 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 6/200
# 14/14 [==============================] - 3s 234ms/step - loss: 1.3729 - accuracy: 0.9988 - val_loss: 1.7499 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 7/200
# 14/14 [==============================] - 3s 239ms/step - loss: 1.0802 - accuracy: 1.0000 - val_loss: 1.5027 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 8/200
# 14/14 [==============================] - 4s 254ms/step - loss: 0.8544 - accuracy: 1.0000 - val_loss: 1.2959 - val_accuracy: 0.7708 - lr: 0.0010
# Epoch 9/200
# 14/14 [==============================] - 3s 244ms/step - loss: 0.6803 - accuracy: 0.9988 - val_loss: 1.1801 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 10/200
# 14/14 [==============================] - 3s 247ms/step - loss: 0.5630 - accuracy: 1.0000 - val_loss: 1.0942 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 11/200
# 14/14 [==============================] - 3s 251ms/step - loss: 0.4712 - accuracy: 1.0000 - val_loss: 0.9992 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 12/200
# 14/14 [==============================] - 3s 242ms/step - loss: 0.3947 - accuracy: 1.0000 - val_loss: 0.8920 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 13/200
# 14/14 [==============================] - 3s 232ms/step - loss: 0.3281 - accuracy: 1.0000 - val_loss: 0.8267 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 14/200
# 14/14 [==============================] - 3s 242ms/step - loss: 0.2736 - accuracy: 1.0000 - val_loss: 0.7747 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 15/200
# 14/14 [==============================] - 3s 235ms/step - loss: 0.2318 - accuracy: 1.0000 - val_loss: 0.7506 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 16/200
# 14/14 [==============================] - 3s 240ms/step - loss: 0.1978 - accuracy: 1.0000 - val_loss: 0.7075 - val_accuracy: 0.7708 - lr: 0.0010
# Epoch 17/200
# 14/14 [==============================] - 4s 255ms/step - loss: 0.1721 - accuracy: 1.0000 - val_loss: 0.6909 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 18/200
# 14/14 [==============================] - 4s 270ms/step - loss: 0.1544 - accuracy: 1.0000 - val_loss: 0.6882 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 19/200
# 14/14 [==============================] - 4s 268ms/step - loss: 0.1401 - accuracy: 1.0000 - val_loss: 0.6708 - val_accuracy: 0.7708 - lr: 0.0010
# Epoch 20/200
# 14/14 [==============================] - 3s 238ms/step - loss: 0.1467 - accuracy: 1.0000 - val_loss: 0.8665 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 21/200
# 14/14 [==============================] - 3s 240ms/step - loss: 0.1855 - accuracy: 0.9964 - val_loss: 1.1236 - val_accuracy: 0.6042 - lr: 0.0010
# Epoch 22/200
# 14/14 [==============================] - 3s 248ms/step - loss: 0.8480 - accuracy: 0.9139 - val_loss: 2.5597 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 23/200
# 14/14 [==============================] - 4s 290ms/step - loss: 2.9523 - accuracy: 0.8983 - val_loss: 4.9352 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 24/200
# 14/14 [==============================] - 4s 253ms/step - loss: 4.7604 - accuracy: 0.9175 - val_loss: 6.2768 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 25/200
# 14/14 [==============================] - 3s 246ms/step - loss: 5.1360 - accuracy: 0.9653 - val_loss: 6.2485 - val_accuracy: 0.6875 - lr: 5.0000e-04
# Epoch 26/200
# 14/14 [==============================] - 3s 237ms/step - loss: 4.8992 - accuracy: 0.9868 - val_loss: 5.9150 - val_accuracy: 0.7188 - lr: 5.0000e-04
# Epoch 27/200
# 14/14 [==============================] - 4s 254ms/step - loss: 4.4934 - accuracy: 0.9940 - val_loss: 5.4022 - val_accuracy: 0.7292 - lr: 5.0000e-04
# Epoch 28/200
# 14/14 [==============================] - 3s 248ms/step - loss: 4.0850 - accuracy: 0.9952 - val_loss: 5.0198 - val_accuracy: 0.7292 - lr: 5.0000e-04
# Epoch 29/200
# 14/14 [==============================] - 4s 253ms/step - loss: 3.7027 - accuracy: 0.9988 - val_loss: 4.7360 - val_accuracy: 0.7083 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 35ms/step
# 3/3 [==============================] - 0s 35ms/step
# Validation Accuracy: 77.08
# Validation Sensitivity (Recall): 66.67
# Validation Specificity: 87.50
# Validation AUC-ROC Score: 83.46
# Validation Confusion Matrix:
# [[42  6]
#  [16 32]]
# Validation Mean Accuracy: 72.36
# Validation Mean Sensitivity (Recall): 67.71
# Validation Mean Specificity: 77.00
# Validation Mean AUC-ROC Score: 77.91
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 33ms/step
# Test Accuracy: 78.57
# Test Sensitivity (Recall): 82.14
# Test Specificity: 75.00
# Test AUC-ROC Score: 81.76
# Test Confusion Matrix:
# [[21  7]
#  [ 5 23]]
# Test Mean Accuracy: 74.55
# Test Mean Sensitivity (Recall): 76.79
# Test Mean Specificity: 72.32
# Test Mean AUC-ROC Score: 80.99
# Split # 5
# Balance of classes in training - ASD: 420, TC: 420
# Balance of classes in validation - ASD: 46, TC: 46
# Shape of X_train: (840, 26570)
# Shape of y_train: (840,)
# Shape of X_validation: (92, 26570)
# Shape of y_validation: (92,)
# Epoch 1/200
# 14/14 [==============================] - 6s 280ms/step - loss: 3.0741 - accuracy: 0.6202 - val_loss: 3.1573 - val_accuracy: 0.6522 - lr: 0.0010
# Epoch 2/200
# 14/14 [==============================] - 3s 237ms/step - loss: 2.6895 - accuracy: 0.9714 - val_loss: 3.1561 - val_accuracy: 0.7174 - lr: 0.0010
# Epoch 3/200
# 14/14 [==============================] - 3s 250ms/step - loss: 2.4014 - accuracy: 1.0000 - val_loss: 2.8747 - val_accuracy: 0.7609 - lr: 0.0010
# Epoch 4/200
# 14/14 [==============================] - 3s 241ms/step - loss: 1.9929 - accuracy: 0.9976 - val_loss: 2.5106 - val_accuracy: 0.7283 - lr: 0.0010
# Epoch 5/200
# 14/14 [==============================] - 3s 252ms/step - loss: 1.5494 - accuracy: 0.9988 - val_loss: 2.0786 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 6/200
# 14/14 [==============================] - 3s 250ms/step - loss: 1.1850 - accuracy: 0.9988 - val_loss: 1.6997 - val_accuracy: 0.7283 - lr: 0.0010
# Epoch 7/200
# 14/14 [==============================] - 3s 241ms/step - loss: 0.8798 - accuracy: 0.9988 - val_loss: 1.4284 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 8/200
# 14/14 [==============================] - 3s 248ms/step - loss: 0.6670 - accuracy: 0.9988 - val_loss: 1.2481 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 9/200
# 14/14 [==============================] - 3s 232ms/step - loss: 0.5111 - accuracy: 1.0000 - val_loss: 1.1134 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 10/200
# 14/14 [==============================] - 3s 235ms/step - loss: 0.3971 - accuracy: 1.0000 - val_loss: 0.9984 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 11/200
# 14/14 [==============================] - 3s 242ms/step - loss: 0.3141 - accuracy: 1.0000 - val_loss: 0.9372 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 12/200
# 14/14 [==============================] - 3s 234ms/step - loss: 0.2523 - accuracy: 1.0000 - val_loss: 0.8571 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 13/200
# 14/14 [==============================] - 3s 232ms/step - loss: 0.2072 - accuracy: 1.0000 - val_loss: 0.8807 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 14/200
# 14/14 [==============================] - 3s 251ms/step - loss: 0.1753 - accuracy: 1.0000 - val_loss: 0.8441 - val_accuracy: 0.7174 - lr: 0.0010
# Epoch 15/200
# 14/14 [==============================] - 4s 283ms/step - loss: 0.1531 - accuracy: 0.9988 - val_loss: 0.8362 - val_accuracy: 0.7283 - lr: 0.0010
# Epoch 16/200
# 14/14 [==============================] - 4s 290ms/step - loss: 0.1566 - accuracy: 0.9976 - val_loss: 0.8440 - val_accuracy: 0.7065 - lr: 0.0010
# Epoch 17/200
# 14/14 [==============================] - 3s 244ms/step - loss: 0.1810 - accuracy: 0.9976 - val_loss: 1.1793 - val_accuracy: 0.6413 - lr: 0.0010
# Epoch 18/200
# 14/14 [==============================] - 4s 253ms/step - loss: 0.3580 - accuracy: 0.9857 - val_loss: 1.7329 - val_accuracy: 0.5870 - lr: 0.0010
# Epoch 19/200
# 14/14 [==============================] - 3s 250ms/step - loss: 1.1525 - accuracy: 0.9250 - val_loss: 2.9100 - val_accuracy: 0.7174 - lr: 0.0010
# Epoch 20/200
# 14/14 [==============================] - 3s 240ms/step - loss: 2.4639 - accuracy: 0.9286 - val_loss: 3.6420 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 21/200
# 14/14 [==============================] - 3s 244ms/step - loss: 3.0868 - accuracy: 0.9476 - val_loss: 4.0046 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 22/200
# 14/14 [==============================] - 3s 250ms/step - loss: 2.8898 - accuracy: 0.9893 - val_loss: 3.7320 - val_accuracy: 0.7500 - lr: 5.0000e-04
# Epoch 23/200
# 14/14 [==============================] - 3s 242ms/step - loss: 2.5849 - accuracy: 0.9988 - val_loss: 3.3612 - val_accuracy: 0.7391 - lr: 5.0000e-04
# Epoch 24/200
# 14/14 [==============================] - 3s 244ms/step - loss: 2.2510 - accuracy: 0.9988 - val_loss: 3.0724 - val_accuracy: 0.7391 - lr: 5.0000e-04
# Epoch 25/200
# 14/14 [==============================] - 3s 241ms/step - loss: 1.9437 - accuracy: 0.9988 - val_loss: 2.8163 - val_accuracy: 0.7391 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 26ms/step
# 3/3 [==============================] - 0s 29ms/step
# Validation Accuracy: 72.83
# Validation Sensitivity (Recall): 78.26
# Validation Specificity: 67.39
# Validation AUC-ROC Score: 76.28
# Validation Confusion Matrix:
# [[31 15]
#  [10 36]]
# Validation Mean Accuracy: 72.45
# Validation Mean Sensitivity (Recall): 69.82
# Validation Mean Specificity: 75.08
# Validation Mean AUC-ROC Score: 77.58
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 19ms/step
# Test Accuracy: 75.00
# Test Sensitivity (Recall): 75.00
# Test Specificity: 75.00
# Test AUC-ROC Score: 80.10
# Test Confusion Matrix:
# [[21  7]
#  [ 7 21]]
# Test Mean Accuracy: 74.64
# Test Mean Sensitivity (Recall): 76.43
# Test Mean Specificity: 72.86
# Test Mean AUC-ROC Score: 80.82
# Split # 6
# Balance of classes in training - ASD: 422, TC: 422
# Balance of classes in validation - ASD: 43, TC: 43
# Shape of X_train: (844, 26570)
# Shape of y_train: (844,)
# Shape of X_validation: (86, 26570)
# Shape of y_validation: (86,)
# Epoch 1/200
# 14/14 [==============================] - 5s 262ms/step - loss: 3.0984 - accuracy: 0.5877 - val_loss: 3.1091 - val_accuracy: 0.6512 - lr: 0.0010
# Epoch 2/200
# 14/14 [==============================] - 3s 221ms/step - loss: 2.7323 - accuracy: 0.9656 - val_loss: 3.1019 - val_accuracy: 0.7326 - lr: 0.0010
# Epoch 3/200
# 14/14 [==============================] - 3s 224ms/step - loss: 2.4563 - accuracy: 0.9964 - val_loss: 2.8791 - val_accuracy: 0.6744 - lr: 0.0010
# Epoch 4/200
# 14/14 [==============================] - 3s 232ms/step - loss: 2.0748 - accuracy: 0.9988 - val_loss: 2.4862 - val_accuracy: 0.7093 - lr: 0.0010
# Epoch 5/200
# 14/14 [==============================] - 3s 228ms/step - loss: 1.6404 - accuracy: 0.9988 - val_loss: 2.0592 - val_accuracy: 0.7558 - lr: 0.0010
# Epoch 6/200
# 14/14 [==============================] - 3s 243ms/step - loss: 1.2530 - accuracy: 1.0000 - val_loss: 1.6871 - val_accuracy: 0.7093 - lr: 0.0010
# Epoch 7/200
# 14/14 [==============================] - 3s 244ms/step - loss: 0.9458 - accuracy: 1.0000 - val_loss: 1.3994 - val_accuracy: 0.6977 - lr: 0.0010
# Epoch 8/200
# 14/14 [==============================] - 3s 242ms/step - loss: 0.7145 - accuracy: 1.0000 - val_loss: 1.2069 - val_accuracy: 0.7093 - lr: 0.0010
# Epoch 9/200
# 14/14 [==============================] - 4s 257ms/step - loss: 0.5489 - accuracy: 0.9976 - val_loss: 1.0546 - val_accuracy: 0.7326 - lr: 0.0010
# Epoch 10/200
# 14/14 [==============================] - 3s 242ms/step - loss: 0.4489 - accuracy: 0.9976 - val_loss: 1.0073 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 11/200
# 14/14 [==============================] - 3s 239ms/step - loss: 0.4000 - accuracy: 0.9988 - val_loss: 0.9671 - val_accuracy: 0.7558 - lr: 0.0010
# Epoch 12/200
# 14/14 [==============================] - 3s 235ms/step - loss: 0.3535 - accuracy: 0.9988 - val_loss: 0.9634 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 13/200
# 14/14 [==============================] - 3s 234ms/step - loss: 0.3483 - accuracy: 1.0000 - val_loss: 1.0141 - val_accuracy: 0.7093 - lr: 0.0010
# Epoch 14/200
# 14/14 [==============================] - 3s 247ms/step - loss: 0.3483 - accuracy: 0.9976 - val_loss: 0.9580 - val_accuracy: 0.7093 - lr: 0.0010
# Epoch 15/200
# 14/14 [==============================] - 3s 237ms/step - loss: 0.3423 - accuracy: 0.9976 - val_loss: 1.1773 - val_accuracy: 0.6279 - lr: 0.0010
# Epoch 16/200
# 14/14 [==============================] - 3s 231ms/step - loss: 0.4057 - accuracy: 0.9929 - val_loss: 1.5485 - val_accuracy: 0.6512 - lr: 0.0010
# Epoch 17/200
# 14/14 [==============================] - 3s 242ms/step - loss: 0.7767 - accuracy: 0.9514 - val_loss: 2.2846 - val_accuracy: 0.6744 - lr: 0.0010
# Epoch 18/200
# 14/14 [==============================] - 3s 231ms/step - loss: 1.8125 - accuracy: 0.9218 - val_loss: 3.3048 - val_accuracy: 0.6977 - lr: 0.0010
# Epoch 19/200
# 14/14 [==============================] - 3s 238ms/step - loss: 2.7909 - accuracy: 0.9431 - val_loss: 4.3074 - val_accuracy: 0.6628 - lr: 0.0010
# Epoch 20/200
# 14/14 [==============================] - 3s 237ms/step - loss: 3.1549 - accuracy: 0.9739 - val_loss: 4.1686 - val_accuracy: 0.6628 - lr: 5.0000e-04
# Epoch 21/200
# 14/14 [==============================] - 3s 241ms/step - loss: 2.9476 - accuracy: 0.9917 - val_loss: 3.8402 - val_accuracy: 0.6744 - lr: 5.0000e-04
# Epoch 22/200
# 14/14 [==============================] - 3s 249ms/step - loss: 2.6375 - accuracy: 0.9964 - val_loss: 3.5054 - val_accuracy: 0.6628 - lr: 5.0000e-04
# Epoch 23/200
# 14/14 [==============================] - 3s 245ms/step - loss: 2.3152 - accuracy: 1.0000 - val_loss: 3.2317 - val_accuracy: 0.6395 - lr: 5.0000e-04
# Epoch 24/200
# 14/14 [==============================] - 3s 239ms/step - loss: 2.0334 - accuracy: 0.9976 - val_loss: 2.9479 - val_accuracy: 0.6512 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 22ms/step
# 3/3 [==============================] - 0s 30ms/step
# Validation Accuracy: 70.93
# Validation Sensitivity (Recall): 72.09
# Validation Specificity: 69.77
# Validation AUC-ROC Score: 76.96
# Validation Confusion Matrix:
# [[30 13]
#  [12 31]]
# Validation Mean Accuracy: 72.20
# Validation Mean Sensitivity (Recall): 70.20
# Validation Mean Specificity: 74.19
# Validation Mean AUC-ROC Score: 77.48
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 23ms/step
# Test Accuracy: 71.43
# Test Sensitivity (Recall): 75.00
# Test Specificity: 67.86
# Test AUC-ROC Score: 80.87
# Test Confusion Matrix:
# [[19  9]
#  [ 7 21]]
# Test Mean Accuracy: 74.11
# Test Mean Sensitivity (Recall): 76.19
# Test Mean Specificity: 72.02
# Test Mean AUC-ROC Score: 80.82
# Split # 7
# Balance of classes in training - ASD: 424, TC: 424
# Balance of classes in validation - ASD: 42, TC: 42
# Shape of X_train: (848, 26570)
# Shape of y_train: (848,)
# Shape of X_validation: (84, 26570)
# Shape of y_validation: (84,)
# Epoch 1/200
# 14/14 [==============================] - 6s 306ms/step - loss: 3.1149 - accuracy: 0.5896 - val_loss: 3.1907 - val_accuracy: 0.6429 - lr: 0.0010
# Epoch 2/200
# 14/14 [==============================] - 4s 258ms/step - loss: 2.7407 - accuracy: 0.9587 - val_loss: 3.1149 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 3/200
# 14/14 [==============================] - 4s 287ms/step - loss: 2.4571 - accuracy: 0.9941 - val_loss: 2.9728 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 4/200
# 14/14 [==============================] - 4s 277ms/step - loss: 2.0799 - accuracy: 0.9976 - val_loss: 2.5735 - val_accuracy: 0.7024 - lr: 0.0010
# Epoch 5/200
# 14/14 [==============================] - 4s 268ms/step - loss: 1.6455 - accuracy: 0.9988 - val_loss: 2.1266 - val_accuracy: 0.6905 - lr: 0.0010
# Epoch 6/200
# 14/14 [==============================] - 4s 258ms/step - loss: 1.2751 - accuracy: 0.9988 - val_loss: 1.7388 - val_accuracy: 0.6905 - lr: 0.0010
# Epoch 7/200
# 14/14 [==============================] - 4s 258ms/step - loss: 0.9528 - accuracy: 0.9988 - val_loss: 1.4664 - val_accuracy: 0.6786 - lr: 0.0010
# Epoch 8/200
# 14/14 [==============================] - 4s 289ms/step - loss: 0.7325 - accuracy: 0.9988 - val_loss: 1.2755 - val_accuracy: 0.7024 - lr: 0.0010
# Epoch 9/200
# 14/14 [==============================] - 4s 287ms/step - loss: 0.5669 - accuracy: 0.9988 - val_loss: 1.1454 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 10/200
# 14/14 [==============================] - 4s 270ms/step - loss: 0.4435 - accuracy: 1.0000 - val_loss: 1.0566 - val_accuracy: 0.6786 - lr: 0.0010
# Epoch 11/200
# 14/14 [==============================] - 4s 260ms/step - loss: 0.3631 - accuracy: 0.9988 - val_loss: 0.9792 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 12/200
# 14/14 [==============================] - 4s 260ms/step - loss: 0.3055 - accuracy: 1.0000 - val_loss: 0.9560 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 13/200
# 14/14 [==============================] - 4s 266ms/step - loss: 0.2683 - accuracy: 0.9976 - val_loss: 0.9217 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 14/200
# 14/14 [==============================] - 4s 256ms/step - loss: 0.2460 - accuracy: 1.0000 - val_loss: 1.0136 - val_accuracy: 0.6905 - lr: 0.0010
# Epoch 15/200
# 14/14 [==============================] - 4s 265ms/step - loss: 0.3098 - accuracy: 0.9953 - val_loss: 1.2670 - val_accuracy: 0.6190 - lr: 0.0010
# Epoch 16/200
# 14/14 [==============================] - 4s 257ms/step - loss: 0.4956 - accuracy: 0.9870 - val_loss: 2.0196 - val_accuracy: 0.6429 - lr: 0.0010
# Epoch 17/200
# 14/14 [==============================] - 3s 249ms/step - loss: 1.1103 - accuracy: 0.9410 - val_loss: 2.9203 - val_accuracy: 0.6548 - lr: 0.0010
# Epoch 18/200
# 14/14 [==============================] - 4s 267ms/step - loss: 2.3609 - accuracy: 0.9139 - val_loss: 3.9685 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 19/200
# 14/14 [==============================] - 4s 265ms/step - loss: 3.0038 - accuracy: 0.9575 - val_loss: 3.9894 - val_accuracy: 0.7024 - lr: 5.0000e-04
# Epoch 20/200
# 14/14 [==============================] - 4s 264ms/step - loss: 2.9458 - accuracy: 0.9894 - val_loss: 3.8682 - val_accuracy: 0.7024 - lr: 5.0000e-04
# Epoch 21/200
# 14/14 [==============================] - 4s 262ms/step - loss: 2.7323 - accuracy: 0.9917 - val_loss: 3.6374 - val_accuracy: 0.7262 - lr: 5.0000e-04
# Epoch 22/200
# 14/14 [==============================] - 4s 271ms/step - loss: 2.4375 - accuracy: 0.9976 - val_loss: 3.3473 - val_accuracy: 0.7262 - lr: 5.0000e-04
# Epoch 23/200
# 14/14 [==============================] - 4s 270ms/step - loss: 2.1677 - accuracy: 0.9976 - val_loss: 3.0884 - val_accuracy: 0.7024 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 35ms/step
# 3/3 [==============================] - 0s 31ms/step
# Validation Accuracy: 71.43
# Validation Sensitivity (Recall): 73.81
# Validation Specificity: 69.05
# Validation AUC-ROC Score: 77.61
# Validation Confusion Matrix:
# [[29 13]
#  [11 31]]
# Validation Mean Accuracy: 72.09
# Validation Mean Sensitivity (Recall): 70.72
# Validation Mean Specificity: 73.46
# Validation Mean AUC-ROC Score: 77.50
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# Test Accuracy: 75.00
# Test Sensitivity (Recall): 85.71
# Test Specificity: 64.29
# Test AUC-ROC Score: 77.42
# Test Confusion Matrix:
# [[18 10]
#  [ 4 24]]
# Test Mean Accuracy: 74.23
# Test Mean Sensitivity (Recall): 77.55
# Test Mean Specificity: 70.92
# Test Mean AUC-ROC Score: 80.34
# Split # 8
# Balance of classes in training - ASD: 426, TC: 426
# Balance of classes in validation - ASD: 41, TC: 41
# Shape of X_train: (852, 26570)
# Shape of y_train: (852,)
# Shape of X_validation: (82, 26570)
# Shape of y_validation: (82,)
# Epoch 1/200
# 14/14 [==============================] - 7s 299ms/step - loss: 3.0919 - accuracy: 0.6045 - val_loss: 3.0843 - val_accuracy: 0.6951 - lr: 0.0010
# Epoch 2/200
# 14/14 [==============================] - 3s 250ms/step - loss: 2.6937 - accuracy: 0.9636 - val_loss: 3.0332 - val_accuracy: 0.6707 - lr: 0.0010
# Epoch 3/200
# 14/14 [==============================] - 4s 263ms/step - loss: 2.3697 - accuracy: 0.9977 - val_loss: 2.7892 - val_accuracy: 0.6951 - lr: 0.0010
# Epoch 4/200
# 14/14 [==============================] - 4s 260ms/step - loss: 1.9619 - accuracy: 0.9977 - val_loss: 2.3510 - val_accuracy: 0.7073 - lr: 0.0010
# Epoch 5/200
# 14/14 [==============================] - 4s 260ms/step - loss: 1.5189 - accuracy: 0.9977 - val_loss: 1.9214 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 6/200
# 14/14 [==============================] - 4s 252ms/step - loss: 1.1512 - accuracy: 0.9988 - val_loss: 1.5893 - val_accuracy: 0.7073 - lr: 0.0010
# Epoch 7/200
# 14/14 [==============================] - 4s 259ms/step - loss: 0.8502 - accuracy: 1.0000 - val_loss: 1.3426 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 8/200
# 14/14 [==============================] - 4s 264ms/step - loss: 0.6338 - accuracy: 1.0000 - val_loss: 1.1558 - val_accuracy: 0.6951 - lr: 0.0010
# Epoch 9/200
# 14/14 [==============================] - 4s 254ms/step - loss: 0.4758 - accuracy: 1.0000 - val_loss: 1.0035 - val_accuracy: 0.7073 - lr: 0.0010
# Epoch 10/200
# 14/14 [==============================] - 4s 266ms/step - loss: 0.3665 - accuracy: 1.0000 - val_loss: 0.9657 - val_accuracy: 0.6951 - lr: 0.0010
# Epoch 11/200
# 14/14 [==============================] - 4s 259ms/step - loss: 0.2911 - accuracy: 1.0000 - val_loss: 0.9176 - val_accuracy: 0.6829 - lr: 0.0010
# Epoch 12/200
# 14/14 [==============================] - 4s 262ms/step - loss: 0.2386 - accuracy: 1.0000 - val_loss: 0.8673 - val_accuracy: 0.6707 - lr: 0.0010
# Epoch 13/200
# 14/14 [==============================] - 4s 252ms/step - loss: 0.1973 - accuracy: 1.0000 - val_loss: 0.8171 - val_accuracy: 0.6829 - lr: 0.0010
# Epoch 14/200
# 14/14 [==============================] - 3s 250ms/step - loss: 0.1721 - accuracy: 0.9977 - val_loss: 0.8260 - val_accuracy: 0.6585 - lr: 0.0010
# Epoch 15/200
# 14/14 [==============================] - 4s 259ms/step - loss: 0.1623 - accuracy: 1.0000 - val_loss: 0.8280 - val_accuracy: 0.6707 - lr: 0.0010
# Epoch 16/200
# 14/14 [==============================] - 5s 342ms/step - loss: 0.1543 - accuracy: 1.0000 - val_loss: 0.7852 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 17/200
# 14/14 [==============================] - 4s 262ms/step - loss: 0.1633 - accuracy: 0.9977 - val_loss: 0.8682 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 18/200
# 14/14 [==============================] - 4s 254ms/step - loss: 0.1870 - accuracy: 0.9965 - val_loss: 1.1382 - val_accuracy: 0.6098 - lr: 0.0010
# Epoch 19/200
# 14/14 [==============================] - 4s 286ms/step - loss: 0.6319 - accuracy: 0.9448 - val_loss: 2.6741 - val_accuracy: 0.6829 - lr: 0.0010
# Epoch 20/200
# 14/14 [==============================] - 4s 280ms/step - loss: 2.1545 - accuracy: 0.9143 - val_loss: 3.9422 - val_accuracy: 0.6707 - lr: 0.0010
# Epoch 21/200
# 14/14 [==============================] - 4s 265ms/step - loss: 3.6043 - accuracy: 0.9155 - val_loss: 5.0449 - val_accuracy: 0.6829 - lr: 0.0010
# Epoch 22/200
# 14/14 [==============================] - 4s 256ms/step - loss: 3.9194 - accuracy: 0.9812 - val_loss: 5.0922 - val_accuracy: 0.6341 - lr: 5.0000e-04
# Epoch 23/200
# 14/14 [==============================] - 4s 253ms/step - loss: 3.6582 - accuracy: 0.9859 - val_loss: 4.7028 - val_accuracy: 0.6463 - lr: 5.0000e-04
# Epoch 24/200
# 14/14 [==============================] - 4s 264ms/step - loss: 3.2502 - accuracy: 0.9941 - val_loss: 4.2789 - val_accuracy: 0.6585 - lr: 5.0000e-04
# Epoch 25/200
# 14/14 [==============================] - 3s 245ms/step - loss: 2.8452 - accuracy: 0.9977 - val_loss: 3.8711 - val_accuracy: 0.6341 - lr: 5.0000e-04
# Epoch 26/200
# 14/14 [==============================] - 4s 255ms/step - loss: 2.4905 - accuracy: 0.9988 - val_loss: 3.6259 - val_accuracy: 0.6585 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 27ms/step
# 3/3 [==============================] - 0s 27ms/step
# Validation Accuracy: 71.95
# Validation Sensitivity (Recall): 70.73
# Validation Specificity: 73.17
# Validation AUC-ROC Score: 77.87
# Validation Confusion Matrix:
# [[30 11]
#  [12 29]]
# Validation Mean Accuracy: 72.07
# Validation Mean Sensitivity (Recall): 70.72
# Validation Mean Specificity: 73.42
# Validation Mean AUC-ROC Score: 77.54
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 24ms/step
# Test Accuracy: 76.79
# Test Sensitivity (Recall): 85.71
# Test Specificity: 67.86
# Test AUC-ROC Score: 85.59
# Test Confusion Matrix:
# [[19  9]
#  [ 4 24]]
# Test Mean Accuracy: 74.55
# Test Mean Sensitivity (Recall): 78.57
# Test Mean Specificity: 70.54
# Test Mean AUC-ROC Score: 80.99
# Split # 9
# Balance of classes in training - ASD: 426, TC: 426
# Balance of classes in validation - ASD: 40, TC: 40
# Shape of X_train: (852, 26570)
# Shape of y_train: (852,)
# Shape of X_validation: (80, 26570)
# Shape of y_validation: (80,)
# Epoch 1/200
# 14/14 [==============================] - 6s 292ms/step - loss: 3.0955 - accuracy: 0.6033 - val_loss: 3.0709 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 2/200
# 14/14 [==============================] - 4s 263ms/step - loss: 2.6844 - accuracy: 0.9707 - val_loss: 3.0667 - val_accuracy: 0.7625 - lr: 0.0010
# Epoch 3/200
# 14/14 [==============================] - 4s 258ms/step - loss: 2.3903 - accuracy: 0.9988 - val_loss: 2.8152 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 4/200
# 14/14 [==============================] - 4s 264ms/step - loss: 1.9726 - accuracy: 1.0000 - val_loss: 2.3847 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 5/200
# 14/14 [==============================] - 4s 255ms/step - loss: 1.5208 - accuracy: 1.0000 - val_loss: 1.9507 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 6/200
# 14/14 [==============================] - 4s 265ms/step - loss: 1.1296 - accuracy: 1.0000 - val_loss: 1.5953 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 7/200
# 14/14 [==============================] - 4s 252ms/step - loss: 0.8294 - accuracy: 1.0000 - val_loss: 1.3295 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 8/200
# 14/14 [==============================] - 3s 250ms/step - loss: 0.6100 - accuracy: 1.0000 - val_loss: 1.1233 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 9/200
# 14/14 [==============================] - 4s 260ms/step - loss: 0.4560 - accuracy: 1.0000 - val_loss: 0.9666 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 10/200
# 14/14 [==============================] - 4s 257ms/step - loss: 0.3479 - accuracy: 1.0000 - val_loss: 0.8734 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 11/200
# 14/14 [==============================] - 4s 268ms/step - loss: 0.2713 - accuracy: 1.0000 - val_loss: 0.8198 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 12/200
# 14/14 [==============================] - 4s 269ms/step - loss: 0.2165 - accuracy: 1.0000 - val_loss: 0.7758 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 13/200
# 14/14 [==============================] - 4s 263ms/step - loss: 0.1773 - accuracy: 1.0000 - val_loss: 0.7672 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 14/200
# 14/14 [==============================] - 3s 248ms/step - loss: 0.1485 - accuracy: 1.0000 - val_loss: 0.7479 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 15/200
# 14/14 [==============================] - 4s 253ms/step - loss: 0.1268 - accuracy: 1.0000 - val_loss: 0.7104 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 16/200
# 14/14 [==============================] - 4s 253ms/step - loss: 0.1118 - accuracy: 1.0000 - val_loss: 0.6717 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 17/200
# 14/14 [==============================] - 4s 260ms/step - loss: 0.1021 - accuracy: 1.0000 - val_loss: 0.6471 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 18/200
# 14/14 [==============================] - 3s 252ms/step - loss: 0.0936 - accuracy: 1.0000 - val_loss: 0.7149 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 19/200
# 14/14 [==============================] - 4s 303ms/step - loss: 0.0877 - accuracy: 1.0000 - val_loss: 0.6723 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 20/200
# 14/14 [==============================] - 4s 261ms/step - loss: 0.1004 - accuracy: 1.0000 - val_loss: 0.9025 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 21/200
# 14/14 [==============================] - 3s 240ms/step - loss: 0.3123 - accuracy: 0.9707 - val_loss: 1.8804 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 22/200
# 14/14 [==============================] - 4s 265ms/step - loss: 1.8477 - accuracy: 0.8850 - val_loss: 4.2226 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 23/200
# 14/14 [==============================] - 3s 239ms/step - loss: 3.4670 - accuracy: 0.8932 - val_loss: 4.6808 - val_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 24/200
# 14/14 [==============================] - 4s 258ms/step - loss: 3.5626 - accuracy: 0.9577 - val_loss: 4.7804 - val_accuracy: 0.6750 - lr: 5.0000e-04
# Epoch 25/200
# 14/14 [==============================] - 3s 240ms/step - loss: 3.3989 - accuracy: 0.9894 - val_loss: 4.5135 - val_accuracy: 0.6875 - lr: 5.0000e-04
# Epoch 26/200
# 14/14 [==============================] - 3s 248ms/step - loss: 3.0883 - accuracy: 0.9918 - val_loss: 4.0926 - val_accuracy: 0.7000 - lr: 5.0000e-04
# Epoch 27/200
# 14/14 [==============================] - 4s 267ms/step - loss: 2.7404 - accuracy: 0.9988 - val_loss: 3.7000 - val_accuracy: 0.6750 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 29ms/step
# 3/3 [==============================] - 0s 26ms/step
# Validation Accuracy: 72.50
# Validation Sensitivity (Recall): 75.00
# Validation Specificity: 70.00
# Validation AUC-ROC Score: 81.06
# Validation Confusion Matrix:
# [[28 12]
#  [10 30]]
# Validation Mean Accuracy: 72.12
# Validation Mean Sensitivity (Recall): 71.19
# Validation Mean Specificity: 73.04
# Validation Mean AUC-ROC Score: 77.93
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 24ms/step
# Test Accuracy: 76.79
# Test Sensitivity (Recall): 82.14
# Test Specificity: 71.43
# Test AUC-ROC Score: 85.33
# Test Confusion Matrix:
# [[20  8]
#  [ 5 23]]
# Test Mean Accuracy: 74.80
# Test Mean Sensitivity (Recall): 78.97
# Test Mean Specificity: 70.63
# Test Mean AUC-ROC Score: 81.48
# Split # 10
# Balance of classes in training - ASD: 428, TC: 428
# Balance of classes in validation - ASD: 39, TC: 39
# Shape of X_train: (856, 26570)
# Shape of y_train: (856,)
# Shape of X_validation: (78, 26570)
# Shape of y_validation: (78,)
# Epoch 1/200
# 14/14 [==============================] - 7s 334ms/step - loss: 3.1016 - accuracy: 0.5876 - val_loss: 3.0736 - val_accuracy: 0.6795 - lr: 0.0010
# Epoch 2/200
# 14/14 [==============================] - 4s 275ms/step - loss: 2.7213 - accuracy: 0.9603 - val_loss: 3.0239 - val_accuracy: 0.7436 - lr: 0.0010
# Epoch 3/200
# 14/14 [==============================] - 4s 274ms/step - loss: 2.4222 - accuracy: 0.9988 - val_loss: 2.7659 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 4/200
# 14/14 [==============================] - 4s 260ms/step - loss: 2.0361 - accuracy: 0.9988 - val_loss: 2.3527 - val_accuracy: 0.7564 - lr: 0.0010
# Epoch 5/200
# 14/14 [==============================] - 4s 263ms/step - loss: 1.5940 - accuracy: 0.9988 - val_loss: 1.9150 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 6/200
# 14/14 [==============================] - 4s 255ms/step - loss: 1.2056 - accuracy: 1.0000 - val_loss: 1.5624 - val_accuracy: 0.7821 - lr: 0.0010
# Epoch 7/200
# 14/14 [==============================] - 4s 255ms/step - loss: 0.8992 - accuracy: 1.0000 - val_loss: 1.3046 - val_accuracy: 0.7821 - lr: 0.0010
# Epoch 8/200
# 14/14 [==============================] - 3s 249ms/step - loss: 0.6694 - accuracy: 1.0000 - val_loss: 1.1223 - val_accuracy: 0.7564 - lr: 0.0010
# Epoch 9/200
# 14/14 [==============================] - 3s 246ms/step - loss: 0.5047 - accuracy: 1.0000 - val_loss: 0.9701 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 10/200
# 14/14 [==============================] - 3s 244ms/step - loss: 0.3856 - accuracy: 1.0000 - val_loss: 0.8462 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 11/200
# 14/14 [==============================] - 4s 261ms/step - loss: 0.3023 - accuracy: 1.0000 - val_loss: 0.7706 - val_accuracy: 0.7821 - lr: 0.0010
# Epoch 12/200
# 14/14 [==============================] - 4s 262ms/step - loss: 0.2431 - accuracy: 1.0000 - val_loss: 0.7458 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 13/200
# 14/14 [==============================] - 4s 256ms/step - loss: 0.1999 - accuracy: 1.0000 - val_loss: 0.7140 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 14/200
# 14/14 [==============================] - 3s 245ms/step - loss: 0.1670 - accuracy: 1.0000 - val_loss: 0.6801 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 15/200
# 14/14 [==============================] - 3s 211ms/step - loss: 0.1406 - accuracy: 1.0000 - val_loss: 0.6597 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 16/200
# 14/14 [==============================] - 3s 219ms/step - loss: 0.1219 - accuracy: 1.0000 - val_loss: 0.6400 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 17/200
# 14/14 [==============================] - 3s 216ms/step - loss: 0.1087 - accuracy: 1.0000 - val_loss: 0.6757 - val_accuracy: 0.7564 - lr: 0.0010
# Epoch 18/200
# 14/14 [==============================] - 3s 216ms/step - loss: 0.1057 - accuracy: 1.0000 - val_loss: 0.6881 - val_accuracy: 0.7179 - lr: 0.0010
# Epoch 19/200
# 14/14 [==============================] - 3s 228ms/step - loss: 0.1870 - accuracy: 0.9918 - val_loss: 1.2693 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 20/200
# 14/14 [==============================] - 3s 216ms/step - loss: 1.1018 - accuracy: 0.9159 - val_loss: 3.0476 - val_accuracy: 0.6026 - lr: 0.0010
# Epoch 21/200
# 14/14 [==============================] - 3s 224ms/step - loss: 2.9053 - accuracy: 0.8984 - val_loss: 4.5028 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 22/200
# 14/14 [==============================] - 3s 205ms/step - loss: 3.8336 - accuracy: 0.9509 - val_loss: 4.7660 - val_accuracy: 0.7051 - lr: 5.0000e-04
# Epoch 23/200
# 14/14 [==============================] - 3s 213ms/step - loss: 3.7111 - accuracy: 0.9860 - val_loss: 4.5504 - val_accuracy: 0.6795 - lr: 5.0000e-04
# Epoch 24/200
# 14/14 [==============================] - 3s 210ms/step - loss: 3.3908 - accuracy: 0.9918 - val_loss: 4.1782 - val_accuracy: 0.7051 - lr: 5.0000e-04
# Epoch 25/200
# 14/14 [==============================] - 3s 211ms/step - loss: 2.9927 - accuracy: 0.9977 - val_loss: 3.8285 - val_accuracy: 0.6923 - lr: 5.0000e-04
# Epoch 26/200
# 14/14 [==============================] - 3s 204ms/step - loss: 2.6393 - accuracy: 0.9953 - val_loss: 3.3927 - val_accuracy: 0.7051 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 18ms/step
# 3/3 [==============================] - 0s 21ms/step
# Validation Accuracy: 76.92
# Validation Sensitivity (Recall): 74.36
# Validation Specificity: 79.49
# Validation AUC-ROC Score: 82.05
# Validation Confusion Matrix:
# [[31  8]
#  [10 29]]
# Validation Mean Accuracy: 72.60
# Validation Mean Sensitivity (Recall): 71.51
# Validation Mean Specificity: 73.69
# Validation Mean AUC-ROC Score: 78.35
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 21ms/step
# Test Accuracy: 76.79
# Test Sensitivity (Recall): 82.14
# Test Specificity: 71.43
# Test AUC-ROC Score: 84.06
# Test Confusion Matrix:
# [[20  8]
#  [ 5 23]]
# Test Mean Accuracy: 75.00
# Test Mean Sensitivity (Recall): 79.29
# Test Mean Specificity: 70.71
# Test Mean AUC-ROC Score: 81.73
