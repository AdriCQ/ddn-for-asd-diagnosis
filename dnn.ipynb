# %% [markdown]
# ## Deep neural network for ASD classification using resting-state fMRI
#
# This notebook evaluate a deep neural network for ASD diagnosis using functionañ time series data from brain regions of interest. The used resting-state fMRI data from the ABIDE dataset were preprocessed by the **Preprocessed Connectome Project (PCP)** using four pipelines, involving 1100 subjects from multiple international sites.
#
# ### Configure the loading data
#
#  The variables necessary for loading the neuroimaging data are defined. The `pipeline` and `atlas` used for preprocessing and ROIs extraction, also the `phenotypic` information included are specified. Additionally, list all neuroimaging sites available in the dataset and those that are to be included in the analysis are selected using the `sites` and `test_site` variables.

# %%
pipeline = 'cpac'  
rois = 'rois_cc200'
phenotypic = 'all_cases'

# List of all available neuroimaging sites in the dataset
all_sites = [
    'caltech', 'cmu', 'kki', 'leuven_1', 'leuven_2', 'max_mun', 'nyu', 
    'ohsu', 'olin', 'pitt', 'sbl', 'sdsu', 'stanford', 'trinity', 
    'ucla_1', 'ucla_2', 'um_1', 'um_2', 'usm', 'yale'
]

# Sites include in the analysis
sites = all_sites

# Designated site for external testing
test_site = 'yale'

# %% [markdown]
# ### ROIs data loading function
#
# Definition of the `load_rois_data(pipeline, rois, sites, phenotypic)` function to retrieve subject time series and diagnostic labels from each neuroimaging site in `sites`. This function reads `phenotypic` information from CSV files, then loads the time series data for each subject. Also handle potential issues, such as missing files or NaN values, to ensure data integrity before analysis.

# %%
import os
import csv
import numpy as np


def load_rois_data(pipeline, rois, sites, phenotypic):
    """
    Loads time series and diagnostic labels from neuroimaging data files for the specified sites.
    
    Parameters:
        pipeline (str): Preprocessing pipeline used for the data.
        rois (str): Atlas defining regions of interest.
        sites (list of str): List of site names to load data from.

    Returns:
        rois_time_series (dict): Contains time series data for each site.
        rois_labels (dict): Contains diagnostic labels for each site.
    """

    rois_time_series = {}  # Dictionary to store time series data for each site
    rois_labels = {}  # Dictionary to store labels for each site

    for site in sites:
        # Define path for phenotypic data for the current site
        phenotypic_path = f"data/phenotypic/{phenotypic}/{site}/phenotypic.csv"

        try:
            with open(phenotypic_path, 'r') as file:
                reader = csv.DictReader(file)
                site_time_series = []  # List to store time series for each subject at the site
                site_labels = []  # List to store labels for each subject at the site

                for row in reader:
                    file_id = row['file_id']  # Unique subject identifier
                    dx_group = row['dx_group']  # Diagnostic group (ASD=1, Control=0)

                    # Define path for the time series data file
                    data_file_path = os.path.join(f"data/{pipeline}/{rois}/{site}/{file_id}_{rois}.1D")

                    # Check if the data file exists
                    if not os.path.exists(data_file_path):
                        print(f"File Not Found Error: Data file not found at path {data_file_path}")
                        continue
                    
                    data = np.loadtxt(data_file_path)

                    # Check for NaN values and add time series to the site list
                    if np.isnan(data).any():
                        print(f"Value Error: NaN value found for subject {file_id}")
                    else:
                        site_time_series.append(data)
                        site_labels.append(1 if dx_group == '1' else 0)  # Assign 1 for ASD, 0 for control

                # Store loaded data for the current site in the dictionaries
                rois_time_series[site] = site_time_series
                rois_labels[site] = np.array(site_labels)
                print(f"Loaded {len(site_time_series)} subjects from site {site}.")
                
        except FileNotFoundError:
            print(f"File Not Found Error: Phenotypic data not found for site {site}")

    return rois_time_series, rois_labels

# %% [markdown]
# Load data to be used in the analysis based on specified parameters.

# %%
rois_time_series, rois_labels = load_rois_data(pipeline, rois, sites, phenotypic)
# Out:
# Loaded 38 subjects from site caltech.
# Loaded 27 subjects from site cmu.
# Loaded 55 subjects from site kki.
# Loaded 29 subjects from site leuven_1.
# Loaded 35 subjects from site leuven_2.
# Loaded 57 subjects from site max_mun.
# Loaded 184 subjects from site nyu.
# Loaded 28 subjects from site ohsu.
# Loaded 36 subjects from site olin.
# Loaded 57 subjects from site pitt.
# Loaded 30 subjects from site sbl.
# Loaded 36 subjects from site sdsu.
# Loaded 40 subjects from site stanford.
# Loaded 49 subjects from site trinity.
# Loaded 73 subjects from site ucla_1.
# Loaded 26 subjects from site ucla_2.
# Loaded 108 subjects from site um_1.
# Loaded 35 subjects from site um_2.
# Loaded 101 subjects from site usm.
# Loaded 56 subjects from site yale.

# %% [markdown]
# ### Tangent space embedding
#
# This method allows the translation of connectivity matrices from fMRI data into a form that is compatible with Euclidean machine learning techniques while preserving the important geometric properties of the data. Is particularly useful when analyzing covariance or correlation matrices in tasks involving brain connectivity and classification of neurological conditions.
#
# The workflow involves two main steps:
#
# **Estimate the reference tangent space**: Calculate the tangent space projection based on the mean covariance matrix of a training population. This establishes the "reference space" against which individual test subjects can later be projected.
#
# **Project subjects onto the reference space**: Using the precomputed reference tangent space from the population, can be project the covariance matrix of a new subjects onto this space. This will yield a tangent space connectivity matrix for the subjects that aligns with those of the population.
#
# #### Create training population function
#
# Definition of the `create_population(time_series_data)` function for combine the time series into array. To maintain a separate testing set, we exclude the `test_site` site data from the main population data used for estimate the reference tangent space.

# %%
def create_population(time_series_data):
    # Initialize an empty list for the population data 
    population_data = []

    # Loop through the time series data
    for item in time_series_data:
        # Extend each item
        population_data.extend(item)

    print(f"Total subjects in population data: {len(population_data)}")
    return population_data

# %% [markdown]
# #### Function to estimating tangent space functional connectivity
#
# Definition of the `estimate_tangent_space(data)` function calculate the tangent space based on the geometric mean covariance matrix of a training population dataset. This creates a "reference space" that reflects the average connectivity patterns across the population.
#
# The tangent space representation of functional connectivity is a powerful tool for analyzing brain connectivity. It allows the comparison of individual functional connectivity matrices in a standardized space, computed relative to a group average matrix.

# %%
from nilearn.connectome import ConnectivityMeasure

def estimate_tangent_space(data):
    """
    Estimate the tangent space functional connectivity.

    Parameters:
    -----------
    data : list or ndarray
        List or array of time series data for the training population, where each entry corresponds 
        to a subject's time series (time points x regions).

    Returns:
    --------
    ConnectivityMeasure
        Fitted ConnectivityMeasure object configured for tangent space transformation.
    """
    # Instantiate ConnectivityMeasure for tangent space, vectorizing and discarding the diagonal
    connectivity_measure = ConnectivityMeasure(kind='tangent', vectorize=True, discard_diagonal=True)

    # Fit the measure on the population data to establish a reference tangent space
    connectivity_measure.fit(data)

    return connectivity_measure

# %% [markdown]
# ### Deep neural network model building function
#
# Definition of the `build_model(input_shape)` function create DNN models with the following architecture:
#
# Input Layer: Takes in the number of features from the input data.
#
# Dense Layer 1: 128 neurons, ReLU activation, with L2 regularization to reduce overfitting.
#
# Dense Layer 2: 64 neurons, ReLU activation, L2 regularization.
#
# Output Layer: A single neuron with sigmoid activation for binary classification.
#
# The model is compiled with the Adam optimizer and binary cross-entropy loss, as we aim to classify subjects into two classes. We also include accuracy as a performance metric to track model performance during training and evaluation.

# %%
from keras import layers, models, regularizers

# Define the deep neural network model architecture
def build_model(input_shape):
    """
    Builds and compiles a deep neural network model for binary classification.

    Parameters:
    - input_shape: int, the shape of the input layer, matching the number of features in the dataset

    Returns:
    - model: compiled Keras Sequential model ready for training
    """
    
    model = models.Sequential()

    # Input layer
    model.add(layers.InputLayer(input_shape=input_shape))
    model.add(layers.Dropout(0.2))

    # Hidden layers
    model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dropout(0.4))

    model.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
    model.add(layers.Dropout(0.4))

    # Output layer for binary classification (ASD vs. Healthy)
    model.add(layers.Dense(1, activation='sigmoid'))

    # Compile the model with Adam optimizer and binary cross-entropy loss
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %% [markdown]
# ### Definition of training callbacks
#
# To optimize training, we set up three callbacks:
#
# **EarlyStopping:** Stops training if validation loss doesn't improve for 10 epochs, preventing overfitting and restoring the best weights.
#
# **ReduceLROnPlateau:** Reduces the learning rate by 50% when validation loss plateaus for 5 epochs, ensuring gradual and effective model convergence.
#
# **ModelCheckpoint:** Saves the model with the best validation loss to 'best_model.keras', allowing easy access to the optimal version of the model.

# %%
from keras import callbacks

# Early stopping to prevent overfitting by stopping training when validation loss stops improving
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',             # Monitor validation loss for early stopping
    patience=10,                    # Stop training if val_loss does not improve for 10 epochs
    restore_best_weights=True       # Restore the model weights from the epoch with the lowest val_loss
)

# Reduce learning rate when the validation loss plateaus
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',             # Monitor validation loss for learning rate reduction
    factor=0.5,                     # Reduce learning rate by a factor of 0.5
    patience=5,                     # Trigger after 5 epochs without improvement in val_loss
    min_lr=1e-5                     # Set a floor on the learning rate to avoid overly small values
)

# Save the best model based on validation loss
checkpoint = callbacks.ModelCheckpoint(
    'best_model.keras',             # Filename for the best model
    monitor='val_loss',             # Monitor validation loss for checkpoint saving
    save_best_only=True             # Only save the model when it achieves a new best val_loss
)

# Callbacks list passed to the model
callbacks_list = [early_stopping, reduce_lr, checkpoint]

# %% [markdown]
# ### Adjust class balance function
#
# Definition of the `adjust_class_balance(indices, labels)` function for ensures equal representation of all classes by undersampling the majority class(es). This is particularly important in supervised learning, where imbalanced classes can lead to biased models. The function return shuffled list of indices representing a class-balanced subset of the dataset.

# %%
import numpy as np

def adjust_class_balance(indices, labels):
    """
    Adjusts the balance of classes by undersampling the majority class.

    Parameters:
    ----------
    indices : list or ndarray
        Indices of the dataset.
    labels : list or ndarray
        Class labels corresponding to the indices.

    Returns:
    -------
    balanced_indices : ndarray
        Indices of the balanced dataset.
    """
    # Class labels to consider
    CLASS_LABELS = [0, 1]

    # Separate indices by class
    class_indices = {label: [idx for idx in indices if labels[idx] == label] for label in CLASS_LABELS}

    # Determine the minimum class count
    min_class_count = min(len(indices) for indices in class_indices.values())

    # Adjust class balance by undersampling the majority class
    balanced_indices = []
    for label, class_list in class_indices.items():
        if len(class_list) > min_class_count:
            sampled_indices = np.random.choice(class_list, size=min_class_count, replace=False)
            balanced_indices.extend(sampled_indices)
        else:
            balanced_indices.extend(class_list)

    # Shuffle the indices for randomization
    np.random.shuffle(balanced_indices)
    return np.array(balanced_indices)

# %% [markdown]
# ### Stratified cross-validation setup for model training and validation
#
# Set up stratified 10-fold cross-validation for each site (excluding `test_site`) to evaluate model performance across multiple splits. Here’s an overview of the process:
#
# **Stratified k-folds**: StratifiedKFold let to maintain the balance of classes (ASD vs. NC) across each fold, reducing potential bias.
#
# **Fold processing**: For each site, 10 training and validation folds are generated, and indices are stored in the `train_indices` and `val_indices` dictionaries. To ensure class balance after combining all group folds for training data the majority class in each site is undersampling.
#
# **Class balance checks**: For each fold, the balance of ASD and NC samples is shown to confirm each split maintains similar distributions.

# %%
from sklearn.model_selection import StratifiedKFold

# Number of cross-validation folds
n_folds = 10

# Dictionaries for save the training and validation indices
train_indices = {}
val_indices = {}

# Perform stratified k-fold cross-validation for each site, excluding 'test_site' for testing
for site in sites:
    if site == test_site:
        continue

    features = rois_time_series[site]
    labels = rois_labels[site]

    # Initialize StratifiedKFold with shuffle to ensure data randomization
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True)
    
    site_train_indices = []
    site_val_indices = []

    # Loop through each fold in the stratified split
    for fold, (train_idx, val_idx) in enumerate(skf.split(features, labels)):
        print(f"Processing fold #{fold} for site `{site}`")
      
        train_idx = adjust_class_balance(train_idx, labels)
        val_idx = adjust_class_balance(val_idx, labels)

        # Append training and validation indices for each fold
        site_train_indices.append(np.array(train_idx))
        site_val_indices.append(np.array(val_idx))
        
        # Print class distribution for training and validation sets for each fold
        print(f"Balance of classes in training -> ASD: {np.count_nonzero(labels[site_train_indices[fold]] == 1)} and TC: {np.count_nonzero(labels[site_train_indices[fold]] == 0)}")
        
        print(f"Balance of classes in validation -> ASD: {np.count_nonzero(labels[site_val_indices[fold]] == 1)} and TC: {np.count_nonzero(labels[site_val_indices[fold]] == 0)}")

    # Store indices for each fold in the dictionaries
    train_indices[site] = site_train_indices
    val_indices[site] = site_val_indices
# Out:
# Processing fold #0 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `caltech`
# Balance of classes in training -> ASD: 17 and TC: 17
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `cmu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `cmu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `cmu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `cmu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `kki`
# Balance of classes in training -> ASD: 19 and TC: 19
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #4 for site `kki`
# Balance of classes in training -> ASD: 19 and TC: 19
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #5 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `kki`
# Balance of classes in training -> ASD: 20 and TC: 20
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `leuven_1`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `leuven_1`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `leuven_1`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `leuven_1`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `leuven_1`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `leuven_2`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `leuven_2`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `max_mun`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #1 for site `max_mun`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #2 for site `max_mun`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #3 for site `max_mun`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #4 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `max_mun`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #1 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #2 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #3 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #4 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #5 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #6 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #7 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #8 for site `nyu`
# Balance of classes in training -> ASD: 71 and TC: 71
# Balance of classes in validation -> ASD: 8 and TC: 8
# Processing fold #9 for site `nyu`
# Balance of classes in training -> ASD: 72 and TC: 72
# Balance of classes in validation -> ASD: 7 and TC: 7
# Processing fold #0 for site `ohsu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `ohsu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `ohsu`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `ohsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `olin`
# Balance of classes in training -> ASD: 14 and TC: 14
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `olin`
# Balance of classes in training -> ASD: 15 and TC: 15
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `olin`
# Balance of classes in training -> ASD: 15 and TC: 15
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `olin`
# Balance of classes in training -> ASD: 15 and TC: 15
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `olin`
# Balance of classes in training -> ASD: 15 and TC: 15
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #1 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #2 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #3 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #4 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #5 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #6 for site `pitt`
# Balance of classes in training -> ASD: 24 and TC: 24
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #7 for site `pitt`
# Balance of classes in training -> ASD: 25 and TC: 25
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `pitt`
# Balance of classes in training -> ASD: 25 and TC: 25
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `pitt`
# Balance of classes in training -> ASD: 25 and TC: 25
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `sbl`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `sdsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `sdsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `sdsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `sdsu`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `sdsu`
# Balance of classes in training -> ASD: 13 and TC: 13
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `stanford`
# Balance of classes in training -> ASD: 18 and TC: 18
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `trinity`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #1 for site `trinity`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #2 for site `trinity`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `trinity`
# Balance of classes in training -> ASD: 21 and TC: 21
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #6 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #7 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #8 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #9 for site `trinity`
# Balance of classes in training -> ASD: 22 and TC: 22
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #0 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #1 for site `ucla_1`
# Balance of classes in training -> ASD: 28 and TC: 28
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #2 for site `ucla_1`
# Balance of classes in training -> ASD: 28 and TC: 28
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #3 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #4 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #5 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #6 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #7 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #8 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #9 for site `ucla_1`
# Balance of classes in training -> ASD: 29 and TC: 29
# Balance of classes in validation -> ASD: 3 and TC: 3
# Processing fold #0 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #3 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #4 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #5 for site `ucla_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `ucla_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `ucla_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `ucla_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `ucla_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `um_1`
# Balance of classes in training -> ASD: 47 and TC: 47
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #1 for site `um_1`
# Balance of classes in training -> ASD: 47 and TC: 47
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #2 for site `um_1`
# Balance of classes in training -> ASD: 47 and TC: 47
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #3 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #4 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #5 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #6 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #7 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #8 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #9 for site `um_1`
# Balance of classes in training -> ASD: 48 and TC: 48
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #0 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #1 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #2 for site `um_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #3 for site `um_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #4 for site `um_2`
# Balance of classes in training -> ASD: 11 and TC: 11
# Balance of classes in validation -> ASD: 2 and TC: 2
# Processing fold #5 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #6 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #7 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #8 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #9 for site `um_2`
# Balance of classes in training -> ASD: 12 and TC: 12
# Balance of classes in validation -> ASD: 1 and TC: 1
# Processing fold #0 for site `usm`
# Balance of classes in training -> ASD: 38 and TC: 38
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #1 for site `usm`
# Balance of classes in training -> ASD: 38 and TC: 38
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #2 for site `usm`
# Balance of classes in training -> ASD: 38 and TC: 38
# Balance of classes in validation -> ASD: 5 and TC: 5
# Processing fold #3 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #4 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #5 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #6 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #7 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #8 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4
# Processing fold #9 for site `usm`
# Balance of classes in training -> ASD: 39 and TC: 39
# Balance of classes in validation -> ASD: 4 and TC: 4

# %% [markdown]
# ###  Evaluation metrics function
#
# Definition of the `calculate_metrics(y_true, y_pred, y_pred_prob)` function to evaluate the performance of a binary classification model. The function computes several key metrics using true labels (y_true), predicted labels (y_pred), and predicted probabilities (y_pred_prob). These metrics include:
#
# **Accuracy**: The proportion of correct predictions among all predictions.
#
# **Sensitivity (Recall)**: The ability to correctly identify positive cases.
#
# **Precision**: The proportion of true positive predictions among all positive predictions.
# **Specificity**: The ability to correctly identify negative cases.
#
# **Area Under the Curve (AUC)**: Measures the ability of the model to distinguish between classes.
# **Confusion Matrix**: Summarizes true/false positives and negatives.
#
# The function handles edge cases where division by zero might occur, ensuring stability in metric computation. This is essential for evaluating the performance of deep learning models in ASD classification tasks.

# %%
from sklearn.metrics import confusion_matrix, roc_auc_score

def calculate_metrics(y_true, y_pred, y_pred_prob):
    """
    Calculate key evaluation metrics for binary classification tasks.

    Parameters:
    -----------
    y_true : array-like
        Ground truth (true labels).
    y_pred : array-like
        Predicted labels (binary).
    y_pred_prob : array-like
        Predicted probabilities for the positive class.

    Returns:
    --------
    accuracy : float
        Proportion of correctly predicted instances.
    sensitivity : float
        True positive rate (recall for the positive class).
    precision : float
        Precision for the positive class.
    specificity : float
        True negative rate (recall for the negative class).
    auc : float
        Area Under the Receiver Operating Characteristic Curve (ROC AUC).
    cm : ndarray
        Confusion matrix as a NumPy array.
    """
    # Compute confusion matrix and unpack values
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()
    
    # Calculate metrics with safeguards against division by zero
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    auc = roc_auc_score(y_true, y_pred_prob)
    
    return accuracy, sensitivity, precision, specificity, auc, cm

# %% [markdown]
# ### Function to print metrics
# Definition of the `print_metrics(split, dataset_type, accuracy, sensitivity, precision, specificity, auc, cm)` function, which displays key evaluation metrics for a specific dataset split and type. The function is designed to enhance interpretability during model evaluation by printing the following metrics in a well-formatted manner:
#
# **Accuracy**: The overall correctness of predictions.
#
# **Sensitivity (Recall)**: The ability to correctly detect positive cases.
#
# **Precision**: The reliability of positive predictions.
#
# **Specificity**: The ability to correctly detect negative cases.
#
# **AUC-ROC Score**: The model’s ability to distinguish between positive and negative classes.
#
# **Confusion Matrix**: A tabular summary of prediction outcomes (true positives, false positives, etc.).
#
# The parameters allow for flexible use across various dataset types (e.g., training, validation, test) and splits during cross-validation. For example, split helps track metrics for a specific fold in k-fold cross-validation, while dataset_type differentiates between datasets. The metrics are displayed as percentages for better readability.

# %%
def print_metrics(split, dataset_type, accuracy, sensitivity, precision, specificity, auc, cm):
    """
    Display evaluation metrics for a specific data split and dataset type.

    Parameters:
    -----------
    split : int
        The current split index (zero-based).
    dataset_type : str
        The type of dataset (e.g., "training", "validation", "test").
    accuracy : float
        Proportion of correctly predicted instances.
    sensitivity : float
        True positive rate (recall for the positive class).
    precision : float
        Precision for the positive class.
    specificity : float
        True negative rate (recall for the negative class).
    auc : float
        Area Under the Receiver Operating Characteristic Curve (ROC AUC).
    cm : ndarray
        Confusion matrix as a NumPy array.

    Returns:
    --------
    None
    """
    print(f"\n{dataset_type.capitalize()} Metrics for Split {split + 1}:")
    print(f"  Accuracy: {accuracy * 100:.2f}%")
    print(f"  Sensitivity (Recall): {sensitivity * 100:.2f}%")
    print(f"  Precision: {precision * 100:.2f}%")
    print(f"  Specificity: {specificity * 100:.2f}%")
    print(f"  AUC-ROC Score: {auc * 100:.2f}%")
    print(f"  Confusion Matrix:\n{cm}")

# %% [markdown]
# ### Saving tangent spaces
#
# Prepare connectivity matrices in the tangent space representation for each fold of cross-validation.
#
# **Steps**:
#
# **Initialization**: The `connectivity_list` is created to store tangent space representations for each split.
#
# **Cross-validation Loop**:
# Iterates through each fold defined by n_folds.
# Initializes lists to store training and validation time series data (`X_train_time_series`, `X_val_time_series`) and their corresponding labels (`y_train`, `y_val`).
#
# **Site-Specific Aggregation**:
# For each site, the function aggregates data while excluding the predefined `test_site` for external testing.
# Training and validation data are selected based on indices for the current split.
#
# **Tangent Space Representation**:
# The estimate_tangent_space function is applied to the training data to extract the tangent space representation, which is then appended to `connectivity_list`.
# **Output**:
#
# A list of tangent space representations (`connectivity_list`) for training data across all cross-validation folds.

# %%
connectivity_list = []

# Perform cross-validation across all splits
for split in range(n_folds):
    print(f"\n--- Split {split + 1} ---")

    # Initialize lists for training and validation data
    X_train_time_series, X_val_time_series = [], []
    y_train, y_val = [], []

    # Aggregate data from all sites except the test site
    for site in sites:
        if site == test_site:  # Skip the test site
            continue

        # Add training data for the current split
        X_train_time_series.extend(
            rois_time_series[site][idx] for idx in train_indices[site][split]
        )
        y_train.extend(
            rois_labels[site][idx] for idx in train_indices[site][split]
        )

        # Add validation data for the current split
        X_val_time_series.extend(
            rois_time_series[site][idx] for idx in val_indices[site][split]
        )
        y_val.extend(
            rois_labels[site][idx] for idx in val_indices[site][split]
        )

    # Estimate tangent space representation for training data
    connectivity_m = estimate_tangent_space(X_train_time_series)
    connectivity_list.append(connectivity_m)
# Out:
# --- Split 1 ---
#
# --- Split 2 ---
#
# --- Split 3 ---
#
# --- Split 4 ---
#
# --- Split 5 ---
#
# --- Split 6 ---
#
# --- Split 7 ---
#
# --- Split 8 ---
#
# --- Split 9 ---
#
# --- Split 10 ---

# %% [markdown]
# ### Training, validation and testing DNN
#
# Training, validating, and testing a DL model using cross-validation. It calculates and aggregates performance metrics across all folds, culminating in mean metrics for both validation and test datasets.
#
# 1. **Initialization**:
#    - A `metrics` dictionary is initialized to store cumulative performance metrics (accuracy, sensitivity, precision, specificity, and AUC) for validation and test datasets.
#
# 2. **Cross-Validation Process**:
#    - The loop iterates over the number of folds (`n_folds`), performing the following steps for each split:
#      - **Data Aggregation**:
#        - Training and validation data are collected across all sites, excluding the test site. Functional connectivity features are prepared by transforming time series data into tangent space representations.
#      - **Dataset Preparation**:
#        - The training, validation, and test datasets are converted into NumPy arrays for compatibility with the model.
#      - **Dataset Statistics**:
#        - The shapes and class distributions of the datasets are printed for transparency.
#
# 3. **Model Training**:
#    - A DNN model is built and trained on the training dataset (`X_train`, `y_train`). Validation data (`X_val`, `y_val`) is used to monitor the training process.
#
# 4. **Evaluation**:
#    - **Validation Set**:
#      - Predictions are generated, and metrics are calculated using a helper function (`calculate_metrics`). Results are printed and added to the cumulative metrics for validation.
#    - **Test Set**:
#      - The same process is applied to evaluate the model on the test dataset. Results are added to the cumulative metrics for the test.
#
# 5. **Mean Metric Calculation**:
#    - After completing all splits, mean performance metrics are calculated for both validation and test datasets by dividing cumulative values by the number of folds (`n_folds`).
#
# 6. **Output**:
#    - The mean metrics for validation and test datasets are printed, summarizing the model’s performance across all folds.

# %%
# Initialize accumulators for metrics
metrics = {
    "validation": {"accuracy": 0, "sensitivity": 0, "precision": 0, "specificity": 0, "auc": 0},
    "test": {"accuracy": 0, "sensitivity": 0, "precision": 0, "specificity": 0, "auc": 0}
}

# Cross-validation across all splits
for split in range(n_folds):
    print(f"\n--- Split {split + 1} ---")

    # Aggregate training and validation data across all sites
    X_train_time_series, X_val_time_series = [], []
    y_train, y_val = [], []

    for site in sites:
        if site == test_site:
            continue
        X_train_time_series.extend([rois_time_series[site][idx] for idx in train_indices[site][split]])
        y_train.extend([rois_labels[site][idx] for idx in train_indices[site][split]])
        X_val_time_series.extend([rois_time_series[site][idx] for idx in val_indices[site][split]])
        y_val.extend([rois_labels[site][idx] for idx in val_indices[site][split]])

    # Prepare tangent space for feature extraction
    X_train = connectivity_list[split].transform(X_train_time_series)
    X_val = connectivity_list[split].transform(X_val_time_series)
    X_test = connectivity_list[split].transform(rois_time_series[test_site])
    y_test = rois_labels[test_site]

    X_train, X_val, X_test = map(np.array, [X_train, X_val, X_test])
    y_train, y_val, y_test = map(np.array, [y_train, y_val, y_test])

    # Print dataset statistics
    print(f"Training set shape: {X_train.shape}, class balance: ASD={np.sum(y_train == 1)}, TC={np.sum(y_train == 0)}")
    print(f"Validation set shape: {X_val.shape}, class balance: ASD={np.sum(y_val == 1)}, TC={np.sum(y_val == 0)}")
    print(f"Test set shape: {X_test.shape}, class balance: ASD={np.sum(y_test == 1)}, TC={np.sum(y_test == 0)}")

    # Build and train the model
    dnn = build_model(X_train.shape[1])
    history = dnn.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=100, callbacks=callbacks_list)

    # Evaluate on validation set
    validation_pred_prob = dnn.predict(X_val).ravel()
    validation_pred = (validation_pred_prob > 0.5).astype(int)
    acc, sens, prec, spec, auc, cm = calculate_metrics(y_val, validation_pred, validation_pred_prob)
    metrics["validation"]["accuracy"] += acc
    metrics["validation"]["sensitivity"] += sens
    metrics["validation"]["precision"] += prec
    metrics["validation"]["specificity"] += spec
    metrics["validation"]["auc"] += auc
    print_metrics(split, "validation", acc, sens, prec, spec, auc, cm)

    # Evaluate on test set
    test_pred_prob = dnn.predict(X_test).ravel()
    test_pred = (test_pred_prob > 0.5).astype(int)
    acc, sens, prec, spec, auc, cm = calculate_metrics(y_test, test_pred, test_pred_prob)
    metrics["test"]["accuracy"] += acc
    metrics["test"]["sensitivity"] += sens
    metrics["test"]["precision"] += prec
    metrics["test"]["specificity"] += spec
    metrics["test"]["auc"] += auc
    print_metrics(split, "test", acc, sens, prec, spec, auc, cm)

# Print mean metrics
for dataset in metrics:
    print(f"\n--- Mean {dataset.capitalize()} Metrics Across All Splits ---")
    for metric, value in metrics[dataset].items():
        print(f"{metric.capitalize()}: {(value / n_folds) * 100:.2f}%")
# Out:
# --- Split 1 ---
# Training set shape: (834, 19900), class balance: ASD=417, TC=417
# Validation set shape: (94, 19900), class balance: ASD=47, TC=47
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 37ms/step - loss: 1.0326 - accuracy: 0.5959 - val_loss: 1.0132 - val_accuracy: 0.7128 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8092 - accuracy: 0.8609 - val_loss: 0.9699 - val_accuracy: 0.7447 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.5960 - accuracy: 0.9616 - val_loss: 0.9810 - val_accuracy: 0.7128 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4807 - accuracy: 0.9928 - val_loss: 0.9499 - val_accuracy: 0.6915 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.4125 - accuracy: 0.9988 - val_loss: 0.9248 - val_accuracy: 0.7234 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3614 - accuracy: 0.9976 - val_loss: 0.8984 - val_accuracy: 0.7021 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.3191 - accuracy: 0.9988 - val_loss: 0.8653 - val_accuracy: 0.6915 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.2808 - accuracy: 0.9988 - val_loss: 0.8410 - val_accuracy: 0.7340 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2431 - accuracy: 1.0000 - val_loss: 0.8017 - val_accuracy: 0.7128 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.2120 - accuracy: 1.0000 - val_loss: 0.7556 - val_accuracy: 0.7128 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1857 - accuracy: 1.0000 - val_loss: 0.7249 - val_accuracy: 0.7340 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1629 - accuracy: 1.0000 - val_loss: 0.7161 - val_accuracy: 0.7234 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1501 - accuracy: 0.9988 - val_loss: 0.7144 - val_accuracy: 0.7447 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1379 - accuracy: 0.9988 - val_loss: 0.6995 - val_accuracy: 0.7447 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.1210 - accuracy: 1.0000 - val_loss: 0.6867 - val_accuracy: 0.7447 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.1138 - accuracy: 0.9988 - val_loss: 0.6868 - val_accuracy: 0.7660 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1054 - accuracy: 1.0000 - val_loss: 0.6581 - val_accuracy: 0.7447 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1008 - accuracy: 1.0000 - val_loss: 0.6979 - val_accuracy: 0.7234 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1034 - accuracy: 0.9988 - val_loss: 0.7909 - val_accuracy: 0.7234 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.1247 - accuracy: 0.9976 - val_loss: 0.9128 - val_accuracy: 0.6915 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1453 - accuracy: 0.9988 - val_loss: 1.0103 - val_accuracy: 0.6915 - lr: 0.0010
# Epoch 22/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2479 - accuracy: 0.9820 - val_loss: 1.3906 - val_accuracy: 0.6596 - lr: 0.0010
# Epoch 23/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.5811 - accuracy: 0.9424 - val_loss: 1.3317 - val_accuracy: 0.7766 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.5767 - accuracy: 0.9688 - val_loss: 1.5576 - val_accuracy: 0.7340 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.5329 - accuracy: 0.9928 - val_loss: 1.5937 - val_accuracy: 0.6915 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5251 - accuracy: 0.9916 - val_loss: 1.5029 - val_accuracy: 0.7021 - lr: 5.0000e-04
# Epoch 27/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4969 - accuracy: 0.9964 - val_loss: 1.4593 - val_accuracy: 0.7128 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 4ms/step
#
# Validation Metrics for Split 1:
#   Accuracy: 74.47%
#   Sensitivity (Recall): 76.60%
#   Precision: 73.47%
#   Specificity: 72.34%
#   AUC-ROC Score: 82.80%
#   Confusion Matrix:
# [[34 13]
#  [11 36]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 1:
#   Accuracy: 73.21%
#   Sensitivity (Recall): 85.71%
#   Precision: 68.57%
#   Specificity: 60.71%
#   AUC-ROC Score: 83.42%
#   Confusion Matrix:
# [[17 11]
#  [ 4 24]]
#
# --- Split 2 ---
# Training set shape: (832, 19900), class balance: ASD=416, TC=416
# Validation set shape: (96, 19900), class balance: ASD=48, TC=48
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 26/26 [==============================] - 2s 36ms/step - loss: 1.0346 - accuracy: 0.5709 - val_loss: 1.0478 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.8143 - accuracy: 0.8594 - val_loss: 1.0834 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.5742 - accuracy: 0.9688 - val_loss: 1.1453 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.4516 - accuracy: 0.9964 - val_loss: 1.1417 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.3916 - accuracy: 0.9988 - val_loss: 1.1251 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 1s 31ms/step - loss: 0.3405 - accuracy: 1.0000 - val_loss: 1.1471 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.3013 - accuracy: 1.0000 - val_loss: 1.1336 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 8/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.2790 - accuracy: 1.0000 - val_loss: 1.1052 - val_accuracy: 0.6875 - lr: 5.0000e-04
# Epoch 9/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.2566 - accuracy: 1.0000 - val_loss: 1.0997 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 10/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2355 - accuracy: 1.0000 - val_loss: 1.0811 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 11/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.2151 - accuracy: 1.0000 - val_loss: 1.0531 - val_accuracy: 0.6875 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 4ms/step
#
# Validation Metrics for Split 2:
#   Accuracy: 59.38%
#   Sensitivity (Recall): 70.83%
#   Precision: 57.63%
#   Specificity: 47.92%
#   AUC-ROC Score: 65.19%
#   Confusion Matrix:
# [[23 25]
#  [14 34]]
# 2/2 [==============================] - 0s 4ms/step
#
# Test Metrics for Split 2:
#   Accuracy: 75.00%
#   Sensitivity (Recall): 67.86%
#   Precision: 79.17%
#   Specificity: 82.14%
#   AUC-ROC Score: 79.72%
#   Confusion Matrix:
# [[23  5]
#  [ 9 19]]
#
# --- Split 3 ---
# Training set shape: (830, 19900), class balance: ASD=415, TC=415
# Validation set shape: (98, 19900), class balance: ASD=49, TC=49
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 26/26 [==============================] - 2s 38ms/step - loss: 1.0398 - accuracy: 0.5783 - val_loss: 1.0528 - val_accuracy: 0.6020 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.7961 - accuracy: 0.8747 - val_loss: 1.0762 - val_accuracy: 0.6020 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.5610 - accuracy: 0.9771 - val_loss: 1.1151 - val_accuracy: 0.6224 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 1s 33ms/step - loss: 0.4501 - accuracy: 0.9952 - val_loss: 1.1306 - val_accuracy: 0.6224 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.3945 - accuracy: 0.9976 - val_loss: 1.0967 - val_accuracy: 0.6531 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.3418 - accuracy: 0.9988 - val_loss: 1.0567 - val_accuracy: 0.6327 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.3045 - accuracy: 1.0000 - val_loss: 1.0407 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 8/100
# 26/26 [==============================] - 1s 31ms/step - loss: 0.2849 - accuracy: 0.9976 - val_loss: 1.0184 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 9/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2602 - accuracy: 1.0000 - val_loss: 1.0090 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 10/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2395 - accuracy: 1.0000 - val_loss: 0.9982 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 11/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2259 - accuracy: 0.9976 - val_loss: 0.9839 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 12/100
# 26/26 [==============================] - 1s 34ms/step - loss: 0.2077 - accuracy: 0.9988 - val_loss: 0.9666 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 13/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1875 - accuracy: 1.0000 - val_loss: 0.9451 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 14/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1713 - accuracy: 1.0000 - val_loss: 0.9255 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 15/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.1578 - accuracy: 1.0000 - val_loss: 0.9168 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 16/100
# 26/26 [==============================] - 1s 32ms/step - loss: 0.1451 - accuracy: 1.0000 - val_loss: 0.9211 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 17/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.1344 - accuracy: 1.0000 - val_loss: 0.9183 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 18/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.1228 - accuracy: 1.0000 - val_loss: 0.9104 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 19/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.1144 - accuracy: 1.0000 - val_loss: 0.9079 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 20/100
# 26/26 [==============================] - 1s 33ms/step - loss: 0.1077 - accuracy: 1.0000 - val_loss: 0.9062 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 21/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0991 - accuracy: 1.0000 - val_loss: 0.9093 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 22/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.0919 - accuracy: 1.0000 - val_loss: 0.9021 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 23/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0863 - accuracy: 1.0000 - val_loss: 0.9101 - val_accuracy: 0.6633 - lr: 5.0000e-04
# Epoch 24/100
# 26/26 [==============================] - 1s 34ms/step - loss: 0.0812 - accuracy: 1.0000 - val_loss: 0.9218 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 25/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0768 - accuracy: 1.0000 - val_loss: 0.9352 - val_accuracy: 0.6531 - lr: 5.0000e-04
# Epoch 26/100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.9385 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 27/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0687 - accuracy: 1.0000 - val_loss: 0.9495 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 28/100
# 26/26 [==============================] - 1s 34ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 0.9484 - val_accuracy: 0.6531 - lr: 2.5000e-04
# Epoch 29/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.0640 - accuracy: 1.0000 - val_loss: 0.9428 - val_accuracy: 0.6429 - lr: 2.5000e-04
# Epoch 30/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.0621 - accuracy: 1.0000 - val_loss: 0.9353 - val_accuracy: 0.6531 - lr: 2.5000e-04
# Epoch 31/100
# 26/26 [==============================] - 1s 34ms/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.9317 - val_accuracy: 0.6531 - lr: 2.5000e-04
# Epoch 32/100
# 26/26 [==============================] - 1s 30ms/step - loss: 0.0586 - accuracy: 1.0000 - val_loss: 0.9315 - val_accuracy: 0.6429 - lr: 2.5000e-04
# 4/4 [==============================] - 0s 3ms/step
#
# Validation Metrics for Split 3:
#   Accuracy: 65.31%
#   Sensitivity (Recall): 63.27%
#   Precision: 65.96%
#   Specificity: 67.35%
#   AUC-ROC Score: 71.80%
#   Confusion Matrix:
# [[33 16]
#  [18 31]]
# 2/2 [==============================] - 0s 4ms/step
#
# Test Metrics for Split 3:
#   Accuracy: 80.36%
#   Sensitivity (Recall): 85.71%
#   Precision: 77.42%
#   Specificity: 75.00%
#   AUC-ROC Score: 84.57%
#   Confusion Matrix:
# [[21  7]
#  [ 4 24]]
#
# --- Split 4 ---
# Training set shape: (836, 19900), class balance: ASD=418, TC=418
# Validation set shape: (96, 19900), class balance: ASD=48, TC=48
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 40ms/step - loss: 1.0483 - accuracy: 0.5156 - val_loss: 1.0432 - val_accuracy: 0.6354 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8529 - accuracy: 0.8469 - val_loss: 1.0256 - val_accuracy: 0.6146 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.6304 - accuracy: 0.9522 - val_loss: 1.0412 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4881 - accuracy: 0.9916 - val_loss: 1.0602 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4253 - accuracy: 0.9952 - val_loss: 1.0671 - val_accuracy: 0.6354 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3691 - accuracy: 1.0000 - val_loss: 1.0594 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3209 - accuracy: 0.9988 - val_loss: 1.0378 - val_accuracy: 0.6146 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.2880 - accuracy: 1.0000 - val_loss: 1.0138 - val_accuracy: 0.6042 - lr: 5.0000e-04
# Epoch 9/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2668 - accuracy: 0.9988 - val_loss: 0.9816 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 10/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2439 - accuracy: 1.0000 - val_loss: 0.9646 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 11/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2261 - accuracy: 1.0000 - val_loss: 0.9525 - val_accuracy: 0.6458 - lr: 5.0000e-04
# Epoch 12/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2077 - accuracy: 1.0000 - val_loss: 0.9353 - val_accuracy: 0.6458 - lr: 5.0000e-04
# Epoch 13/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1919 - accuracy: 1.0000 - val_loss: 0.9192 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 14/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1769 - accuracy: 1.0000 - val_loss: 0.9115 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 15/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1617 - accuracy: 1.0000 - val_loss: 0.9109 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 16/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1496 - accuracy: 1.0000 - val_loss: 0.8975 - val_accuracy: 0.6458 - lr: 5.0000e-04
# Epoch 17/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1381 - accuracy: 1.0000 - val_loss: 0.8966 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 18/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1285 - accuracy: 1.0000 - val_loss: 0.8864 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 19/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1182 - accuracy: 1.0000 - val_loss: 0.8842 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 20/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1111 - accuracy: 1.0000 - val_loss: 0.8929 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 21/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1066 - accuracy: 0.9988 - val_loss: 0.8667 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0998 - accuracy: 1.0000 - val_loss: 0.8917 - val_accuracy: 0.6458 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1057 - accuracy: 0.9988 - val_loss: 0.8503 - val_accuracy: 0.6354 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1036 - accuracy: 0.9988 - val_loss: 0.8316 - val_accuracy: 0.6458 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0935 - accuracy: 0.9988 - val_loss: 0.8476 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0858 - accuracy: 1.0000 - val_loss: 0.8341 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 27/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 0.8413 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 28/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0798 - accuracy: 1.0000 - val_loss: 0.8503 - val_accuracy: 0.6250 - lr: 5.0000e-04
# Epoch 29/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 0.8564 - val_accuracy: 0.6354 - lr: 5.0000e-04
# Epoch 30/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 0.8505 - val_accuracy: 0.6146 - lr: 2.5000e-04
# Epoch 31/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0703 - accuracy: 1.0000 - val_loss: 0.8546 - val_accuracy: 0.6354 - lr: 2.5000e-04
# Epoch 32/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0681 - accuracy: 1.0000 - val_loss: 0.8542 - val_accuracy: 0.6354 - lr: 2.5000e-04
# Epoch 33/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0658 - accuracy: 1.0000 - val_loss: 0.8486 - val_accuracy: 0.6250 - lr: 2.5000e-04
# Epoch 34/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0640 - accuracy: 1.0000 - val_loss: 0.8471 - val_accuracy: 0.6354 - lr: 2.5000e-04
# 3/3 [==============================] - 0s 5ms/step
#
# Validation Metrics for Split 4:
#   Accuracy: 64.58%
#   Sensitivity (Recall): 60.42%
#   Precision: 65.91%
#   Specificity: 68.75%
#   AUC-ROC Score: 74.31%
#   Confusion Matrix:
# [[33 15]
#  [19 29]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 4:
#   Accuracy: 73.21%
#   Sensitivity (Recall): 75.00%
#   Precision: 72.41%
#   Specificity: 71.43%
#   AUC-ROC Score: 83.42%
#   Confusion Matrix:
# [[20  8]
#  [ 7 21]]
#
# --- Split 5 ---
# Training set shape: (840, 19900), class balance: ASD=420, TC=420
# Validation set shape: (92, 19900), class balance: ASD=46, TC=46
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 42ms/step - loss: 1.0301 - accuracy: 0.6048 - val_loss: 1.0446 - val_accuracy: 0.6630 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.7721 - accuracy: 0.8881 - val_loss: 1.0455 - val_accuracy: 0.6848 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.5454 - accuracy: 0.9726 - val_loss: 1.0481 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4471 - accuracy: 0.9964 - val_loss: 1.0572 - val_accuracy: 0.6630 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.3842 - accuracy: 0.9988 - val_loss: 1.0485 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3313 - accuracy: 1.0000 - val_loss: 1.0262 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2835 - accuracy: 1.0000 - val_loss: 1.0086 - val_accuracy: 0.7065 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.2445 - accuracy: 1.0000 - val_loss: 0.9841 - val_accuracy: 0.7065 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2097 - accuracy: 1.0000 - val_loss: 0.9682 - val_accuracy: 0.7065 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1806 - accuracy: 1.0000 - val_loss: 0.9102 - val_accuracy: 0.7065 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.1581 - accuracy: 1.0000 - val_loss: 0.8779 - val_accuracy: 0.7174 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1387 - accuracy: 1.0000 - val_loss: 0.8759 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1226 - accuracy: 1.0000 - val_loss: 0.8860 - val_accuracy: 0.7065 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1100 - accuracy: 1.0000 - val_loss: 0.8680 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.1050 - accuracy: 1.0000 - val_loss: 0.9122 - val_accuracy: 0.7065 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 0.8821 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.8741 - val_accuracy: 0.7283 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0890 - accuracy: 1.0000 - val_loss: 0.9384 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0891 - accuracy: 1.0000 - val_loss: 0.9678 - val_accuracy: 0.6957 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0931 - accuracy: 1.0000 - val_loss: 1.0358 - val_accuracy: 0.6630 - lr: 5.0000e-04
# Epoch 21/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0934 - accuracy: 0.9988 - val_loss: 1.0925 - val_accuracy: 0.6739 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0933 - accuracy: 1.0000 - val_loss: 1.1377 - val_accuracy: 0.6196 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0882 - accuracy: 1.0000 - val_loss: 1.1358 - val_accuracy: 0.6413 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 1.1226 - val_accuracy: 0.6630 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 3ms/step
#
# Validation Metrics for Split 5:
#   Accuracy: 69.57%
#   Sensitivity (Recall): 63.04%
#   Precision: 72.50%
#   Specificity: 76.09%
#   AUC-ROC Score: 74.86%
#   Confusion Matrix:
# [[35 11]
#  [17 29]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 5:
#   Accuracy: 76.79%
#   Sensitivity (Recall): 82.14%
#   Precision: 74.19%
#   Specificity: 71.43%
#   AUC-ROC Score: 84.06%
#   Confusion Matrix:
# [[20  8]
#  [ 5 23]]
#
# --- Split 6 ---
# Training set shape: (844, 19900), class balance: ASD=422, TC=422
# Validation set shape: (86, 19900), class balance: ASD=43, TC=43
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 41ms/step - loss: 1.0385 - accuracy: 0.5735 - val_loss: 0.9763 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.7957 - accuracy: 0.8637 - val_loss: 0.8922 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.5752 - accuracy: 0.9716 - val_loss: 0.8518 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4576 - accuracy: 0.9964 - val_loss: 0.8232 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4008 - accuracy: 0.9988 - val_loss: 0.7871 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3530 - accuracy: 1.0000 - val_loss: 0.7266 - val_accuracy: 0.8140 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.3069 - accuracy: 1.0000 - val_loss: 0.6862 - val_accuracy: 0.7791 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2670 - accuracy: 1.0000 - val_loss: 0.6563 - val_accuracy: 0.7791 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2309 - accuracy: 1.0000 - val_loss: 0.6253 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2017 - accuracy: 1.0000 - val_loss: 0.6039 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1759 - accuracy: 1.0000 - val_loss: 0.5699 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1548 - accuracy: 1.0000 - val_loss: 0.5600 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1359 - accuracy: 1.0000 - val_loss: 0.5493 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1216 - accuracy: 1.0000 - val_loss: 0.5195 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1097 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8256 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0990 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.8488 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0901 - accuracy: 1.0000 - val_loss: 0.4660 - val_accuracy: 0.8256 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0837 - accuracy: 1.0000 - val_loss: 0.4923 - val_accuracy: 0.8140 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0792 - accuracy: 1.0000 - val_loss: 0.4543 - val_accuracy: 0.8488 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0777 - accuracy: 0.9988 - val_loss: 0.4613 - val_accuracy: 0.8372 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.0935 - accuracy: 0.9976 - val_loss: 0.8584 - val_accuracy: 0.7558 - lr: 0.0010
# Epoch 22/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2898 - accuracy: 0.9692 - val_loss: 1.7831 - val_accuracy: 0.6047 - lr: 0.0010
# Epoch 23/100
# 27/27 [==============================] - 1s 35ms/step - loss: 1.0415 - accuracy: 0.9064 - val_loss: 1.9561 - val_accuracy: 0.6512 - lr: 0.0010
# Epoch 24/100
# 27/27 [==============================] - 1s 31ms/step - loss: 1.3361 - accuracy: 0.9254 - val_loss: 2.0415 - val_accuracy: 0.6860 - lr: 0.0010
# Epoch 25/100
# 27/27 [==============================] - 1s 31ms/step - loss: 1.2595 - accuracy: 0.9739 - val_loss: 2.0388 - val_accuracy: 0.6744 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 34ms/step - loss: 1.1759 - accuracy: 0.9846 - val_loss: 1.9230 - val_accuracy: 0.7209 - lr: 5.0000e-04
# Epoch 27/100
# 27/27 [==============================] - 1s 33ms/step - loss: 1.1002 - accuracy: 0.9929 - val_loss: 1.8402 - val_accuracy: 0.7209 - lr: 5.0000e-04
# Epoch 28/100
# 27/27 [==============================] - 1s 31ms/step - loss: 1.0233 - accuracy: 0.9953 - val_loss: 1.7371 - val_accuracy: 0.7093 - lr: 5.0000e-04
# Epoch 29/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.9551 - accuracy: 0.9976 - val_loss: 1.6675 - val_accuracy: 0.7093 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 4ms/step
#
# Validation Metrics for Split 6:
#   Accuracy: 84.88%
#   Sensitivity (Recall): 79.07%
#   Precision: 89.47%
#   Specificity: 90.70%
#   AUC-ROC Score: 91.73%
#   Confusion Matrix:
# [[39  4]
#  [ 9 34]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 6:
#   Accuracy: 75.00%
#   Sensitivity (Recall): 89.29%
#   Precision: 69.44%
#   Specificity: 60.71%
#   AUC-ROC Score: 80.36%
#   Confusion Matrix:
# [[17 11]
#  [ 3 25]]
#
# --- Split 7 ---
# Training set shape: (848, 19900), class balance: ASD=424, TC=424
# Validation set shape: (84, 19900), class balance: ASD=42, TC=42
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 40ms/step - loss: 1.0374 - accuracy: 0.5755 - val_loss: 1.0256 - val_accuracy: 0.6310 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7979 - accuracy: 0.8715 - val_loss: 1.0415 - val_accuracy: 0.6310 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.5672 - accuracy: 0.9741 - val_loss: 1.0048 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4528 - accuracy: 0.9941 - val_loss: 1.0182 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.3887 - accuracy: 0.9965 - val_loss: 1.0188 - val_accuracy: 0.6786 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.3347 - accuracy: 0.9976 - val_loss: 0.9228 - val_accuracy: 0.7024 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2910 - accuracy: 0.9988 - val_loss: 0.9022 - val_accuracy: 0.7262 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2470 - accuracy: 1.0000 - val_loss: 0.8868 - val_accuracy: 0.7262 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2119 - accuracy: 1.0000 - val_loss: 0.8756 - val_accuracy: 0.6905 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1812 - accuracy: 1.0000 - val_loss: 0.8637 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1562 - accuracy: 0.9988 - val_loss: 0.8389 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.1372 - accuracy: 1.0000 - val_loss: 0.8266 - val_accuracy: 0.6786 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.1232 - accuracy: 1.0000 - val_loss: 0.8895 - val_accuracy: 0.6548 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1149 - accuracy: 0.9988 - val_loss: 0.8420 - val_accuracy: 0.6429 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.1190 - accuracy: 0.9988 - val_loss: 0.8675 - val_accuracy: 0.6548 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.1033 - accuracy: 0.9988 - val_loss: 0.8559 - val_accuracy: 0.6905 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0929 - accuracy: 1.0000 - val_loss: 0.8788 - val_accuracy: 0.6548 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0869 - accuracy: 1.0000 - val_loss: 0.8553 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 19/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 0.8494 - val_accuracy: 0.6548 - lr: 5.0000e-04
# Epoch 20/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0782 - accuracy: 0.9988 - val_loss: 0.8364 - val_accuracy: 0.6429 - lr: 5.0000e-04
# Epoch 21/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0760 - accuracy: 1.0000 - val_loss: 0.9058 - val_accuracy: 0.6190 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0718 - accuracy: 1.0000 - val_loss: 0.8700 - val_accuracy: 0.6667 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 5ms/step
#
# Validation Metrics for Split 7:
#   Accuracy: 67.86%
#   Sensitivity (Recall): 64.29%
#   Precision: 69.23%
#   Specificity: 71.43%
#   AUC-ROC Score: 76.19%
#   Confusion Matrix:
# [[30 12]
#  [15 27]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 7:
#   Accuracy: 75.00%
#   Sensitivity (Recall): 82.14%
#   Precision: 71.88%
#   Specificity: 67.86%
#   AUC-ROC Score: 82.91%
#   Confusion Matrix:
# [[19  9]
#  [ 5 23]]
#
# --- Split 8 ---
# Training set shape: (852, 19900), class balance: ASD=426, TC=426
# Validation set shape: (82, 19900), class balance: ASD=41, TC=41
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 40ms/step - loss: 1.0439 - accuracy: 0.5728 - val_loss: 1.0028 - val_accuracy: 0.6463 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.8026 - accuracy: 0.8732 - val_loss: 0.9429 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.5630 - accuracy: 0.9742 - val_loss: 0.8879 - val_accuracy: 0.7927 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4474 - accuracy: 0.9930 - val_loss: 0.8791 - val_accuracy: 0.7561 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3886 - accuracy: 1.0000 - val_loss: 0.8437 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.3403 - accuracy: 0.9977 - val_loss: 0.8209 - val_accuracy: 0.7317 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2931 - accuracy: 1.0000 - val_loss: 0.7803 - val_accuracy: 0.7561 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2567 - accuracy: 0.9977 - val_loss: 0.7494 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.2251 - accuracy: 0.9988 - val_loss: 0.7158 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1954 - accuracy: 0.9988 - val_loss: 0.6932 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.1709 - accuracy: 0.9988 - val_loss: 0.6241 - val_accuracy: 0.8049 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1652 - accuracy: 0.9988 - val_loss: 0.6338 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1309 - accuracy: 1.0000 - val_loss: 0.6317 - val_accuracy: 0.7927 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.1142 - accuracy: 1.0000 - val_loss: 0.6241 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.1031 - accuracy: 1.0000 - val_loss: 0.6272 - val_accuracy: 0.7927 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0942 - accuracy: 1.0000 - val_loss: 0.6209 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0853 - accuracy: 1.0000 - val_loss: 0.6242 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0798 - accuracy: 1.0000 - val_loss: 0.5861 - val_accuracy: 0.7683 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.0769 - accuracy: 1.0000 - val_loss: 0.6158 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0786 - accuracy: 1.0000 - val_loss: 0.5468 - val_accuracy: 0.8293 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0972 - accuracy: 0.9965 - val_loss: 0.9137 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 22/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.4645 - accuracy: 0.9390 - val_loss: 2.0171 - val_accuracy: 0.6585 - lr: 0.0010
# Epoch 23/100
# 27/27 [==============================] - 1s 33ms/step - loss: 1.1807 - accuracy: 0.9038 - val_loss: 2.0075 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 24/100
# 27/27 [==============================] - 1s 32ms/step - loss: 1.3028 - accuracy: 0.9425 - val_loss: 2.0131 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 25/100
# 27/27 [==============================] - 1s 36ms/step - loss: 1.2038 - accuracy: 0.9777 - val_loss: 1.9072 - val_accuracy: 0.7561 - lr: 0.0010
# Epoch 26/100
# 27/27 [==============================] - 1s 32ms/step - loss: 1.0908 - accuracy: 0.9953 - val_loss: 1.8678 - val_accuracy: 0.7439 - lr: 5.0000e-04
# Epoch 27/100
# 27/27 [==============================] - 1s 31ms/step - loss: 1.0232 - accuracy: 0.9953 - val_loss: 1.8070 - val_accuracy: 0.7561 - lr: 5.0000e-04
# Epoch 28/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.9541 - accuracy: 0.9918 - val_loss: 1.7490 - val_accuracy: 0.7561 - lr: 5.0000e-04
# Epoch 29/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.8855 - accuracy: 0.9977 - val_loss: 1.6824 - val_accuracy: 0.7439 - lr: 5.0000e-04
# Epoch 30/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.8310 - accuracy: 0.9977 - val_loss: 1.6192 - val_accuracy: 0.7317 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 4ms/step
#
# Validation Metrics for Split 8:
#   Accuracy: 82.93%
#   Sensitivity (Recall): 82.93%
#   Precision: 82.93%
#   Specificity: 82.93%
#   AUC-ROC Score: 88.22%
#   Confusion Matrix:
# [[34  7]
#  [ 7 34]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 8:
#   Accuracy: 75.00%
#   Sensitivity (Recall): 82.14%
#   Precision: 71.88%
#   Specificity: 67.86%
#   AUC-ROC Score: 81.12%
#   Confusion Matrix:
# [[19  9]
#  [ 5 23]]
#
# --- Split 9 ---
# Training set shape: (852, 19900), class balance: ASD=426, TC=426
# Validation set shape: (80, 19900), class balance: ASD=40, TC=40
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 40ms/step - loss: 1.0335 - accuracy: 0.5869 - val_loss: 0.9979 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.7578 - accuracy: 0.8979 - val_loss: 0.9888 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.5415 - accuracy: 0.9824 - val_loss: 0.9760 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4424 - accuracy: 0.9965 - val_loss: 0.9812 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3839 - accuracy: 0.9988 - val_loss: 0.9621 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3323 - accuracy: 1.0000 - val_loss: 0.9339 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2876 - accuracy: 0.9988 - val_loss: 0.9155 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.2470 - accuracy: 1.0000 - val_loss: 0.8696 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2129 - accuracy: 1.0000 - val_loss: 0.8250 - val_accuracy: 0.7625 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.1849 - accuracy: 1.0000 - val_loss: 0.8205 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 38ms/step - loss: 0.1589 - accuracy: 1.0000 - val_loss: 0.8076 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1375 - accuracy: 1.0000 - val_loss: 0.8000 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 38ms/step - loss: 0.1217 - accuracy: 1.0000 - val_loss: 0.7837 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1064 - accuracy: 1.0000 - val_loss: 0.7743 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0953 - accuracy: 1.0000 - val_loss: 0.7442 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 39ms/step - loss: 0.0868 - accuracy: 1.0000 - val_loss: 0.7721 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 0.8301 - val_accuracy: 0.7625 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 38ms/step - loss: 0.0806 - accuracy: 1.0000 - val_loss: 0.8489 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 0.8396 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0771 - accuracy: 1.0000 - val_loss: 0.7666 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 21/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 0.7868 - val_accuracy: 0.7250 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0710 - accuracy: 1.0000 - val_loss: 0.8152 - val_accuracy: 0.7375 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.8055 - val_accuracy: 0.6875 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 0.7646 - val_accuracy: 0.7250 - lr: 5.0000e-04
# Epoch 25/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.7410 - val_accuracy: 0.7625 - lr: 5.0000e-04
# Epoch 26/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 0.7565 - val_accuracy: 0.7125 - lr: 5.0000e-04
# Epoch 27/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.7657 - val_accuracy: 0.7125 - lr: 5.0000e-04
# Epoch 28/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.7933 - val_accuracy: 0.7125 - lr: 5.0000e-04
# Epoch 29/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.0493 - accuracy: 1.0000 - val_loss: 0.7762 - val_accuracy: 0.7250 - lr: 5.0000e-04
# Epoch 30/100
# 27/27 [==============================] - 1s 38ms/step - loss: 0.0528 - accuracy: 0.9977 - val_loss: 0.7431 - val_accuracy: 0.6750 - lr: 5.0000e-04
# Epoch 31/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.7499 - val_accuracy: 0.7125 - lr: 2.5000e-04
# Epoch 32/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.7792 - val_accuracy: 0.7125 - lr: 2.5000e-04
# Epoch 33/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0545 - accuracy: 1.0000 - val_loss: 0.7899 - val_accuracy: 0.7125 - lr: 2.5000e-04
# Epoch 34/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.7953 - val_accuracy: 0.7125 - lr: 2.5000e-04
# Epoch 35/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0501 - accuracy: 1.0000 - val_loss: 0.7785 - val_accuracy: 0.7125 - lr: 2.5000e-04
# 3/3 [==============================] - 0s 4ms/step
#
# Validation Metrics for Split 9:
#   Accuracy: 76.25%
#   Sensitivity (Recall): 77.50%
#   Precision: 75.61%
#   Specificity: 75.00%
#   AUC-ROC Score: 81.19%
#   Confusion Matrix:
# [[30 10]
#  [ 9 31]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 9:
#   Accuracy: 69.64%
#   Sensitivity (Recall): 75.00%
#   Precision: 67.74%
#   Specificity: 64.29%
#   AUC-ROC Score: 78.44%
#   Confusion Matrix:
# [[18 10]
#  [ 7 21]]
#
# --- Split 10 ---
# Training set shape: (856, 19900), class balance: ASD=428, TC=428
# Validation set shape: (78, 19900), class balance: ASD=39, TC=39
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 27/27 [==============================] - 2s 43ms/step - loss: 1.0432 - accuracy: 0.5748 - val_loss: 1.0336 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 2/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.8033 - accuracy: 0.8703 - val_loss: 0.9952 - val_accuracy: 0.7051 - lr: 0.0010
# Epoch 3/100
# 27/27 [==============================] - 1s 40ms/step - loss: 0.5834 - accuracy: 0.9556 - val_loss: 0.9889 - val_accuracy: 0.7308 - lr: 0.0010
# Epoch 4/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4541 - accuracy: 0.9942 - val_loss: 0.9823 - val_accuracy: 0.7051 - lr: 0.0010
# Epoch 5/100
# 27/27 [==============================] - 1s 39ms/step - loss: 0.4028 - accuracy: 0.9942 - val_loss: 0.9670 - val_accuracy: 0.7051 - lr: 0.0010
# Epoch 6/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.3492 - accuracy: 0.9988 - val_loss: 0.9188 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 7/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.2977 - accuracy: 1.0000 - val_loss: 0.8737 - val_accuracy: 0.7051 - lr: 0.0010
# Epoch 8/100
# 27/27 [==============================] - 1s 40ms/step - loss: 0.2542 - accuracy: 1.0000 - val_loss: 0.8443 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 9/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.2200 - accuracy: 1.0000 - val_loss: 0.8175 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 10/100
# 27/27 [==============================] - 1s 40ms/step - loss: 0.1879 - accuracy: 1.0000 - val_loss: 0.7900 - val_accuracy: 0.6795 - lr: 0.0010
# Epoch 11/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.1638 - accuracy: 0.9988 - val_loss: 0.8028 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 12/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1423 - accuracy: 1.0000 - val_loss: 0.8220 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 13/100
# 27/27 [==============================] - 1s 39ms/step - loss: 0.1380 - accuracy: 0.9977 - val_loss: 0.7970 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 14/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1170 - accuracy: 1.0000 - val_loss: 0.7684 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 15/100
# 27/27 [==============================] - 1s 39ms/step - loss: 0.1167 - accuracy: 0.9977 - val_loss: 0.7790 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 16/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1255 - accuracy: 0.9988 - val_loss: 0.7703 - val_accuracy: 0.7436 - lr: 0.0010
# Epoch 17/100
# 27/27 [==============================] - 1s 39ms/step - loss: 0.1387 - accuracy: 0.9988 - val_loss: 0.8755 - val_accuracy: 0.6795 - lr: 0.0010
# Epoch 18/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1268 - accuracy: 0.9965 - val_loss: 1.1214 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 19/100
# 27/27 [==============================] - 1s 35ms/step - loss: 0.1860 - accuracy: 0.9965 - val_loss: 1.2623 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 20/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.2576 - accuracy: 0.9930 - val_loss: 1.4740 - val_accuracy: 0.6154 - lr: 5.0000e-04
# Epoch 21/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2512 - accuracy: 0.9988 - val_loss: 1.4503 - val_accuracy: 0.5897 - lr: 5.0000e-04
# Epoch 22/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.2613 - accuracy: 0.9942 - val_loss: 1.4731 - val_accuracy: 0.6154 - lr: 5.0000e-04
# Epoch 23/100
# 27/27 [==============================] - 1s 36ms/step - loss: 0.2667 - accuracy: 0.9953 - val_loss: 1.4608 - val_accuracy: 0.6026 - lr: 5.0000e-04
# Epoch 24/100
# 27/27 [==============================] - 1s 38ms/step - loss: 0.2588 - accuracy: 0.9988 - val_loss: 1.4200 - val_accuracy: 0.5641 - lr: 5.0000e-04
# 3/3 [==============================] - 0s 4ms/step
#
# Validation Metrics for Split 10:
#   Accuracy: 69.23%
#   Sensitivity (Recall): 66.67%
#   Precision: 70.27%
#   Specificity: 71.79%
#   AUC-ROC Score: 74.95%
#   Confusion Matrix:
# [[28 11]
#  [13 26]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 10:
#   Accuracy: 71.43%
#   Sensitivity (Recall): 82.14%
#   Precision: 67.65%
#   Specificity: 60.71%
#   AUC-ROC Score: 83.29%
#   Confusion Matrix:
# [[17 11]
#  [ 5 23]]
#
# --- Mean Validation Metrics Across All Splits ---
# Accuracy: 71.44%
# Sensitivity: 70.46%
# Precision: 72.30%
# Specificity: 72.43%
# Auc: 78.12%
#
# --- Mean Test Metrics Across All Splits ---
# Accuracy: 74.46%
# Sensitivity: 80.71%
# Precision: 72.03%
# Specificity: 68.21%
# Auc: 82.13%

# %% [markdown]
# ### Training, validation and testing DNN with the whole dataset
#
# Prepares the training and test datasets for the classification model by aggregating data from all sites except the test site and transforming the functional connectivity matrices into feature vectors using tangent space parametrization.
#
# 1. **Data Aggregation**:
#    - The time-series data (`rois_time_series`) and corresponding labels (`rois_labels`) from all sites, except the designated `test_site`, are combined into `X_train_time_series` and `y_data`, respectively.
#
# 2. **Tangent Space Preparation**:
#    - A tangent space model is estimated using the training time-series data by calling the `estimate_tangent_space` function. This step prepares a feature extraction mechanism for transforming the raw data.
#
# 3. **Feature Transformation**:
#    - The tangent space model is applied to both:
#      - `X_train_time_series` to transform training data into feature vectors stored in `X_data`.
#      - `rois_time_series[test_site]` to transform the test site data into feature vectors stored in `X_test`.
#    - The labels for the test set are stored in `y_test`.

# %%
from sklearn.model_selection import train_test_split

# Aggregate all training data
X_train_time_series, y_data = [], []

for site in sites:
    if site == test_site:
        continue

    X_train_time_series.extend(rois_time_series[site])
    y_data.extend(rois_labels[site])

# Prepare tangent space for feature extraction
connectivity_m = estimate_tangent_space(X_train_time_series)
print("Tangent space estimated.")

# Transform data into feature vectors
X_data = connectivity_m.transform(X_train_time_series)
X_test = connectivity_m.transform(rois_time_series[test_site])
y_test = rois_labels[test_site]
# Out:
# Tangent space estimated.

# %% [markdown]
# Handles the data preparation, model training, and evaluation on training, validation, and test datasets.
#
# 1. **Splitting the Data**:
#    - The training data (`X_data`, `y_data`) is split into training (`X_train`, `y_train`) and validation (`X_val`, `y_val`) sets using `train_test_split` with stratification to preserve class balance.
#    - The test set remains separate as `X_test` and `y_test`.
#
# 2. **Data Conversion**:
#    - Training, validation, and test datasets (`X_train`, `X_val`, `X_test`, `y_train`, `y_val`, `y_test`) are converted to numpy arrays for compatibility with the model.
#
# 3. **Dataset Statistics**:
#    - Prints the shapes of the training, validation, and test sets along with the class distribution for `ASD` (positive class) and `TC` (negative class).
#
# 4. **Model Training**:
#    - A deep neural network (DNN) is constructed using the `build_model` function, with the input shape derived from `X_train`.
#    - The model is trained on the training set (`X_train`, `y_train`) and evaluated on the validation set (`X_val`, `y_val`) using:
#      - Batch size: 32
#      - Epochs: 100
#      - Callbacks: `callbacks_list` for monitoring and early stopping.
#
# 5. **Evaluation**:
#    - Predictions and metrics (accuracy, sensitivity, precision, specificity, AUC) are calculated for the following sets:
#      - **Training Set**:
#        - Predictions: `train_pred_prob`, thresholded at 0.5 for binary classification.
#        - Metrics calculated using `calculate_metrics` and printed using `print_metrics`.
#      - **Validation Set**:
#        - Predictions: `val_pred_prob`, thresholded at 0.5 for binary classification.
#        - Metrics calculated and printed as above.
#      - **Test Set**:
#        - Predictions: `test_pred_prob`, thresholded at 0.5 for binary classification.
#        - Metrics calculated and printed as above.

# %%
# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, stratify=y_data, test_size=0.2)

# Convert labels to numpy arrays
X_train, X_val, X_test = map(np.array, [X_train, X_val, X_test])
y_train, y_val, y_test = map(np.array, [y_train, y_val, y_test])

# Print dataset statistics
print(f"Training set shape: {X_train.shape}, class balance: ASD={np.sum(y_train == 1)}, TC={np.sum(y_train == 0)}")
print(f"Validation set shape: {X_val.shape}, class balance: ASD={np.sum(y_val == 1)}, TC={np.sum(y_val == 0)}")
print(f"Test set shape: {X_test.shape}, class balance: ASD={np.sum(y_test == 1)}, TC={np.sum(y_test == 0)}")

# Build and train the model
dnn = build_model(X_train.shape[1])
history = dnn.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=100, callbacks=callbacks_list)

# Evaluate on training set
train_pred_prob = dnn.predict(X_train).ravel()
train_pred = (train_pred_prob > 0.5).astype(int)
acc, sens, prec, spec, auc, cm = calculate_metrics(y_train, train_pred, train_pred_prob)
print_metrics(1, "training", acc, sens, prec, spec, auc, cm)

# Evaluate on validation set
val_pred_prob = dnn.predict(X_val).ravel()
val_pred = (val_pred_prob > 0.5).astype(int)
acc, sens, prec, spec, auc, cm = calculate_metrics(y_val, val_pred, val_pred_prob)
print_metrics(1, "validation", acc, sens, prec, spec, auc, cm)

# Evaluate on test set
test_pred_prob = dnn.predict(X_test).ravel()
test_pred = (test_pred_prob > 0.5).astype(int)
acc, sens, prec, spec, auc, cm = calculate_metrics(y_test, test_pred, test_pred_prob)
print_metrics(1, "test", acc, sens, prec, spec, auc, cm)
# Out:
# Training set shape: (939, 19900), class balance: ASD=451, TC=488
# Validation set shape: (105, 19900), class balance: ASD=50, TC=55
# Test set shape: (56, 19900), class balance: ASD=28, TC=28
# Epoch 1/100
# 30/30 [==============================] - 3s 39ms/step - loss: 1.0403 - accuracy: 0.5985 - val_loss: 1.0015 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 2/100
# 30/30 [==============================] - 1s 30ms/step - loss: 0.7831 - accuracy: 0.8839 - val_loss: 0.9366 - val_accuracy: 0.7238 - lr: 0.0010
# Epoch 3/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.5561 - accuracy: 0.9776 - val_loss: 0.9794 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 4/100
# 30/30 [==============================] - 1s 30ms/step - loss: 0.4480 - accuracy: 0.9968 - val_loss: 0.9418 - val_accuracy: 0.7524 - lr: 0.0010
# Epoch 5/100
# 30/30 [==============================] - 1s 30ms/step - loss: 0.3872 - accuracy: 0.9989 - val_loss: 0.9423 - val_accuracy: 0.7048 - lr: 0.0010
# Epoch 6/100
# 30/30 [==============================] - 1s 30ms/step - loss: 0.3387 - accuracy: 0.9968 - val_loss: 0.9011 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 7/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.2989 - accuracy: 0.9989 - val_loss: 0.8563 - val_accuracy: 0.6952 - lr: 0.0010
# Epoch 8/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.2513 - accuracy: 0.9989 - val_loss: 0.8014 - val_accuracy: 0.7238 - lr: 0.0010
# Epoch 9/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.2150 - accuracy: 1.0000 - val_loss: 0.7489 - val_accuracy: 0.7238 - lr: 0.0010
# Epoch 10/100
# 30/30 [==============================] - 1s 30ms/step - loss: 0.1896 - accuracy: 0.9989 - val_loss: 0.7491 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 11/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1881 - accuracy: 0.9989 - val_loss: 0.7428 - val_accuracy: 0.7048 - lr: 0.0010
# Epoch 12/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1479 - accuracy: 1.0000 - val_loss: 0.7057 - val_accuracy: 0.7238 - lr: 0.0010
# Epoch 13/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.1315 - accuracy: 1.0000 - val_loss: 0.7066 - val_accuracy: 0.7048 - lr: 0.0010
# Epoch 14/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1226 - accuracy: 1.0000 - val_loss: 0.7258 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 15/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1134 - accuracy: 1.0000 - val_loss: 0.6582 - val_accuracy: 0.7238 - lr: 0.0010
# Epoch 16/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1045 - accuracy: 1.0000 - val_loss: 0.7023 - val_accuracy: 0.7333 - lr: 0.0010
# Epoch 17/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1119 - accuracy: 1.0000 - val_loss: 0.8334 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 18/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1203 - accuracy: 1.0000 - val_loss: 1.0715 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 19/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1839 - accuracy: 0.9925 - val_loss: 1.1785 - val_accuracy: 0.6762 - lr: 0.0010
# Epoch 20/100
# 30/30 [==============================] - 1s 30ms/step - loss: 0.7055 - accuracy: 0.9201 - val_loss: 2.3711 - val_accuracy: 0.5905 - lr: 0.0010
# Epoch 21/100
# 30/30 [==============================] - 1s 31ms/step - loss: 1.0772 - accuracy: 0.9318 - val_loss: 2.2800 - val_accuracy: 0.6286 - lr: 5.0000e-04
# Epoch 22/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.9532 - accuracy: 0.9819 - val_loss: 2.3199 - val_accuracy: 0.5905 - lr: 5.0000e-04
# Epoch 23/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.9058 - accuracy: 0.9883 - val_loss: 2.2862 - val_accuracy: 0.5905 - lr: 5.0000e-04
# Epoch 24/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.8387 - accuracy: 0.9904 - val_loss: 2.1625 - val_accuracy: 0.6286 - lr: 5.0000e-04
# Epoch 25/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.7739 - accuracy: 0.9979 - val_loss: 2.0959 - val_accuracy: 0.6381 - lr: 5.0000e-04
# 30/30 [==============================] - 0s 4ms/step
#
# Training Metrics for Split 2:
#   Accuracy: 100.00%
#   Sensitivity (Recall): 100.00%
#   Precision: 100.00%
#   Specificity: 100.00%
#   AUC-ROC Score: 100.00%
#   Confusion Matrix:
# [[488   0]
#  [  0 451]]
# 4/4 [==============================] - 0s 4ms/step
#
# Validation Metrics for Split 2:
#   Accuracy: 72.38%
#   Sensitivity (Recall): 68.00%
#   Precision: 72.34%
#   Specificity: 76.36%
#   AUC-ROC Score: 82.51%
#   Confusion Matrix:
# [[42 13]
#  [16 34]]
# 2/2 [==============================] - 0s 5ms/step
#
# Test Metrics for Split 2:
#   Accuracy: 71.43%
#   Sensitivity (Recall): 64.29%
#   Precision: 75.00%
#   Specificity: 78.57%
#   AUC-ROC Score: 79.21%
#   Confusion Matrix:
# [[22  6]
#  [10 18]]
